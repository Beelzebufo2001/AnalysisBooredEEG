# %%
import mne
import numpy as np 
import matplotlib.pyplot as plt


#path to file
path = "/home/manka-roblik/AnalysisBooredEEG/data/C03/C03_2024-11-17_09-36-49_RS_before_ica.fif" #second file opens itself

#input output reading function
ica = mne.io.read_raw_fif(fname=path, preload=False, verbose=True) #preload=False dokud nechceš aby ti bouchnul laptop

i_montage= mne.channels.make_standard_montage("standard_1005")
ica.set_montage(i_montage)


ica.plot()
# Out:
# Opening raw data file /home/manka-roblik/AnalysisBooredEEG/data/C03/C03_2024-11-17_09-36-49_RS_before_ica.fif...
#     Range : 0 ... 4287999 =      0.000 ...   536.000 secs
# Ready.
# Opening raw data file /home/manka-roblik/AnalysisBooredEEG/data/C03/C03_2024-11-17_09-36-49_RS_before_ica-1.fif...
#     Range : 4288000 ... 4811428 =    536.000 ...   601.428 secs
# Ready.
# /tmp/ipykernel_13206/3314158591.py:10: RuntimeWarning: This filename (/home/manka-roblik/AnalysisBooredEEG/data/C03/C03_2024-11-17_09-36-49_RS_before_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ica = mne.io.read_raw_fif(fname=path, preload=False, verbose=True) #preload=False dokud nechceš aby ti bouchnul laptop
# <mne_qt_browser._pg_figure.MNEQtBrowser(0x55ff345ca4f0) at 0x7527d1fee280>
