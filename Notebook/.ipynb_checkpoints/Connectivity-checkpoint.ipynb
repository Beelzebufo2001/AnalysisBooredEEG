# %% [markdown]
# <h1><span style="color:plum"><b>Connectivity of channels</h1>
# <span style="color:darkmagenta">Theme: Work with connectivity ❀ Create mean ❀ Examine single pairs ❀ Compare time evolution</span>
#
# <h2><span style="color:peachpuff"><b>One Pair: two electrodes</h2>
# First I will plot two electrodes of correlation matrices over time. Next make function to recall them based on names, because there are 7750 of them.
#
# 1) Load matrices in order
# 2) Extract one pair (i, j)
# 3) Store values
# 4) Plot
#
# >Resolution is in 1 second overlap in 10 second windows, which I am gonna keep, since it's still information about connectivity.
# >Keep that in mind in final <span style="color:darkmagenta">"Time(s)"</span> label of the plots...
#
# <h2><span style="color:darkseagreen"><b>Connectivity information:</h2>
#
# I've got connectivity (corelation matrices) for every 10 seconds of data. Which means I know how much are waves similar between two electrodes >> corelation. Hypothesis sounds like this: When brain is bored, the signal connectivity is supposed to go down.
#
# <h3><span style="color:seagreen">Explanation</h3>
# Whenever you calculate the correlation between any two electrodes you are measuring how similar those signals are. If areas interact usually their signal become more similar, even with a small time lag or a phase-locking. <b>Correlation</b> is just the simplest measure of this, but there are many other way to measure how signals depend on each other like the <i> Phase-Locking Value (PLV) or the Granger Causality (GC)</i>, we will use them only if the "simple" correlation shows no effect.
#
# So assuming that correlation is a good way to measure communication between different areas, the thing we are after is how this communication changes over time. So essentially if we calculate the correlation between two electrodes during the first 5 seconds and during the next 5 seconds if nothing changed between them we should have very similar values (there is always some noise). What Ali saw is that as you keep doing this (the next 5 seconds, the next 5 etc until the end) the correlations systematically go down, suggesting lower communication between brain areas. <b>So the hypothesis is that this lower communication indicates/explains/IS the boredom.</b>
#
# <h3><span style="color:seagreen">Now about whether comparing the matrix or the single pair </h3>
# The correlation matrix essentially has the correlation value for every pair of electrodes. It is likely that certain pairs of electrodes (certain index in the correlation matrix) change more over time than others. That is what I would expect, there is probably a certain subset of electrode pairs that change more, because those correspond to the brain areas that are most relevant for the boredom. We cannot see the insula in EEG (it's in the middle of the head), but should be able to see the cortical areas that are related to it.
#
# <b> If you take the average of the entire correlation matrix </b> then you are averaging away all the information about brain areas and looking at the communication in the whole brain. That is fine, seeing changes in the average of the matrix would mean that the changes in communication are widespread. But what can happen is that the average is close to the noise value (maybe some pairs are going up. some others are going down, so on average it stays the same).
#
# It is worthwhile looking at both things, single pairs (there are 124x123 of them per time point) and the whole average (just one number per time point).
#
#                  /\____/\
#                 >•    •  <

# %%
import os
import mne
import numpy as np
import warnings as w
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.signal import decimate
from elephant.signal_processing import butter

line = "\n❀----------------------------------------------------------❀\n"

# %% [markdown]
# <h3><span style="color:lightsteelblue"><b>Load matrices in order and store them into memory </h3>
#
# way to store them: 3D >> np.stack()
#
# ><small> The numpy.stack() function is used to join multiple arrays by creating a new axis in the output array. This means the resulting array always has one extra dimension compared to the input arrays. To stack arrays, they must have the same shape, and NumPy places them along the axis you specify.

# %%
data_sample = "C01"
path = "./Corr_matrices/" + data_sample + "/"

files = sorted([f for f in os.listdir(path) if f.endswith("npy")])

matrices = []

for file in files:
    matrix = np.load(path + file)
    matrices.append(matrix)

connectivity = np.stack(matrices) # TIME, MATRIX
    

upper_indices = np.triu_indices(connectivity.shape[1], k=1) #ij above diagonal hoppefully

print (upper_indices) # really holds only ij numbmers
print (upper_indices[1])
print(len(matrices))
print (connectivity.shape)
# Out:
# (array([  0,   0,   0, ..., 122, 122, 123]), array([  1,   2,   3, ..., 123, 124, 124]))
# [  1   2   3 ... 123 124 124]
# 591
# (591, 125, 125)

# %% [markdown]
# <h3><span style="color:thistle"><b>Extract one pair (i, j) and store the value</h3>

# %%
i = 2
j = 9
values = []
for matrix in matrices:
    values.append(matrix[i, j])
#print(values)

# %% [markdown]
# <h3><span style="color:peachpuff"><b>Plot one connectivity - two electrodes</h3>

# %%
plt.plot(values, color='orange', label= "electrodes")
plt.xlabel('Time (s)')
plt.ylabel('Connection')
plt.show()

# %% [markdown]
# <h3><span style="color:rosybrown"><b>Loading data structure of montage</h3>
#
# Just to be able later work between charackter electron names (Pz, Cp1...) and number nomenclature.

# %%
#Loading data
data_sample = "C01"
path = "./../data/"+ data_sample + "/C01_2024-11-16_10-44-51_RS_before_ica.fif"
with w.catch_warnings():
    w.simplefilter("ignore", RuntimeWarning)
    ica = mne.io.read_raw_fif(path, preload=False)
    
#Setting montage
ica.set_montage(mne.channels.make_standard_montage("standard_1005"))

ch_names = ica.info["ch_names"]
name_to_idx = {name: idx for idx, name in enumerate(ch_names)}
# Out:
# Opening raw data file ./../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif...
#     Range : 0 ... 4287999 =      0.000 ...   536.000 secs
# Ready.
# Opening raw data file /home/manka-roblik/AnalysisBooredEEG/Notebook/../data/C01/C01_2024-11-16_10-44-51_RS_before_ica-1.fif...
#     Range : 4288000 ... 4807672 =    536.000 ...   600.959 secs
# Ready.

# %% [markdown]
# <h2><span style="color:plum"><b>Plot and save all electrodes pair connectivity over time</h2>
#
# Be avare of saving plots of over 7k pairs > takes around 10 minutes. Only asks about file existence, nor if you want them.

# %%
pair_time_series = []
base_dir = "./Plots"
sub_dir = "ElectrodesPairConnectivity"
output_dir = os.path.join(base_dir, sub_dir, data_sample)

if not os.path.exists(base_dir): #Pair
    os.mkdir(base_dir)
if os.path.exists(output_dir): #ElectrodePair...
    print("ElectrodesPairConnectivity folder already exists. Nothing created.")
else:
    os.mkdir(output_dir)
    print("Created ElectrodesPairConnectivity folder. Generating plots...")

    # Build pair time series
    pair_time_series = []

    for i, j in zip(*upper_indices):
        pair_time_series.append(connectivity[:, i, j])

    pair_time_series = np.array(pair_time_series)

    # Plot each pair
    for idx, electrode_pair in enumerate(pair_time_series):
        
        i = upper_indices[0][idx]
        j = upper_indices[1][idx]

        ch1 = ch_names[i]
        ch2 = ch_names[j]

        plt.figure()
        plt.plot(electrode_pair, color='orange')
        plt.title(f"{ch1} - {ch2}")
        plt.xlabel('Time (s)')
        plt.ylabel('Connection')

        filename = f"{ch1}_{ch2}.png"
        filepath = os.path.join(output_dir, filename)

        plt.savefig(filepath)
        plt.close()#For that ram love
# Out:
# ElectrodesPairConnectivity folder already exists. Nothing created.

# %% [markdown]
# <h2><span style="color:rosybrown"><b>Plot by names of electrodes:</h2>
#
# Input names of electrodes or index of electrodes and print plots of their connectivity over time

# %%
base_dir = "./Plots"
sub_dir = "ElectrodesPairConnectivity"
output_dir = os.path.join(base_dir, sub_dir, data_sample)

def printPlot(ch1, ch2):
    
    # If integers were passed, convert to channel names
    if isinstance(ch1, int):
        ch1 = ch_names[ch1]
        
    if isinstance(ch2, int):
        ch2 = ch_names[ch2]

    print(ch1, ch2)
    file_name = f"{ch1}_{ch2}.png"
    file_path = os.path.join(output_dir, file_name)

    if not os.path.exists(file_path):
        file_name = f"{ch2}_{ch1}.png"
        file_path = os.path.join(output_dir, file_name)
        if not os.path.exists(file_path):
            print("Plot does not exist.")
            return

    img = mpimg.imread(file_path)

    plt.figure()
    plt.imshow(img)
    plt.axis("off")
    plt.show()

printPlot("F3", "Pz")

printPlot(10, 3)
# Out:
# F3 Pz
# FC2 F7

# %% [markdown]
# <h2><span style="color:mediumslateblue"><b>Parcour of pattern findingᯓ★</h2>
#
# Im gonna try create metrics which can be use for analysis: distinction.
#
# <span style="color:mediumslateblue"><b>Suggested improvement:
#
# >    a) Mean connectivity over time
# >
# >    b) Variability accross pairs over time
# >
# >    c) Cluster dynamics
# >
# >    d) Which pairs change the most
#
# <span style="color:lightsteelblue"><b> What else can I try
# - Whole mean can flatten the outcome durring reorganisation, but mostly widespread effects
# - I think it would be usefull to look at the most changing arear over time(faster with loosing the overlap)
# - Identify clusters in electrodes (they change in same like way in time,- meaning have kinda similar connectivity over time graphs)
# - I can try indentify ways the signal goes
# - I would love to pick on artifactis which are same for electrodes (like opening eye, etc)

# %% [markdown]
# <h3><span style="color:thistle"><b>a) To be or not to be mean over time</h3>
#
# - for cycle over connectivity
# - make means of every electrode pair
# - plot it
#
# Added mean over time and standard deviation over time

# %%
values = []
for matrix in connectivity:
    val = []
    for i, j in zip(*upper_indices):
        val.append(matrix[i][j])
    mean = np.mean(val)
    values.append(mean)

plt.figure(figsize=(10,3))
plt.plot(values, color='darkmagenta', label="Snipplet of 10s")
plt.title("Mean conectivity over time - widespread effects")
plt.xlabel('Time (s)')
plt.ylabel('Mean connectivity')



print("Avarege global connectivity across the whole recording: ", np.mean(values))
print("how much global connectivity fluctuates over time: ", np.std(values))
# Out:
# Avarege global connectivity across the whole recording:  0.028331472089081777
# how much global connectivity fluctuates over time:  0.009460980901264548

# %% [markdown]
# <span style="color:red"><b>TODO: </span> Plot mean over time for different subject.
# Eletrodes pair is more like addition, like the segments...

# %%
data_sample_list = ["C01", "C02", "C03"]

for data_sample in data_sample_list:
    path = "./Corr_matrices/" + data_sample + "/"
    
    files = sorted([f for f in os.listdir(path) if f.endswith("npy")])
    
    matrices = []
    
    for file in files:
        matrix = np.load(path + file)
        matrices.append(matrix)
    
    connectivity = np.stack(matrices) # TIME, MATRIX
    
    upper_indices = np.triu_indices(connectivity.shape[1], k=1) #ij above diagonal hoppefully
    
    values = []
    for matrix in connectivity:
        pair_vals = matrix[upper_indices]
        mean = np.mean(pair_vals)
        values.append(mean)
    
    plt.figure(figsize=(10,3))
    plt.plot(values, color='darkmagenta', label="Snipplet of 10s")
    plt.title(f"Mean conectivity over time for sample: {data_sample}")
    plt.xlabel('Time (s)')
    plt.ylabel('Mean connectivity')
    plt.show()
    
    print("Avarege global connectivity across the whole recording: ", np.mean(values))
    print("how much global connectivity fluctuates over time: ", np.std(values))

    print(line)
# Out:
# Avarege global connectivity across the whole recording:  0.028331472089081777
# how much global connectivity fluctuates over time:  0.009460980901264548
#
# ❀----------------------------------------------------------❀
# Avarege global connectivity across the whole recording:  0.40146435748542153
# how much global connectivity fluctuates over time:  0.18269663345074824
#
# ❀----------------------------------------------------------❀
# Avarege global connectivity across the whole recording:  0.006103792313574031
# how much global connectivity fluctuates over time:  0.007449207699109495
#
# ❀----------------------------------------------------------❀

# %% [markdown]
# <h3><span style="color:thistle"><b>Comparing first and second half</h3>
#
# <span style="color:red"><b>TODO: </span>Compare first and second half for stattisticaly significant difference. Use mean
#
# <b>About them eyes open and eyes closed</b>:
# <code>print(ica.annotations)</code> is good when there is annotation. When there is not we can guess based on timeline: 10 minutes with 1:1 eo, oc. When there is 590 matrices then 295 is supposed to be the one where change should appear

# %%
data_sample_list = ["C01", "C02", "C03"]
deltas = []
for data_sample in data_sample_list:
    path = "./Corr_matrices/" + data_sample + "/"
    
    files = sorted([f for f in os.listdir(path) if f.endswith("npy")])
    
    matrices = []
    
    for file in files:
        matrix = np.load(path + file)
        matrices.append(matrix)
    
    connectivity = np.stack(matrices) # TIME, MATRIX
    
    upper_indices = np.triu_indices(connectivity.shape[1], k=1) #ij above diagonal hoppefully
    
    values = []
    
    for matrix in connectivity:
        pair_vals = matrix[upper_indices]
        mean = np.mean(pair_vals)
        values.append(mean)
    
    mid = len(values)//2

    plt.figure(figsize=(10,3))
    plt.plot(values, color='thistle')
    plt.axvline(mid, color='darkmagenta', linestyle='--', label="Condition switch")
    
    plt.title(f"Mean connectivity over time for sample: {data_sample}")
    plt.xlabel("Time window")
    plt.ylabel("Mean connectivity")
    plt.legend()
    plt.show()
    
    first_half  = np.mean(values[:mid])
    second_half = np.mean(values[mid:])
    delta = second_half - first_half
    deltas.append(delta)
    
    print("Mean of eyes open: ", first_half)
    print("Mean of eyes closed: ", second_half)
    print("Difference:", delta)
    
    print(line)

plt.bar(range(len(deltas)), deltas)
plt.title("Connectivity change: second half - first half... The fuck ?")
plt.ylabel("Δ connectivity")
plt.show()
# Out:
# Mean of eyes open:  0.02007113637133703
# Mean of eyes closed:  0.036563901267239546
# Difference: 0.016492764895902515
#
# ❀----------------------------------------------------------❀
# Mean of eyes open:  0.41691200063230555
# Mean of eyes closed:  0.3860689023221419
# Difference: -0.03084309831016363
#
# ❀----------------------------------------------------------❀
# Mean of eyes open:  -3.499644196651817e-05
# Mean of eyes closed:  0.01224258106911458
# Difference: 0.012277577511081097
#
# ❀----------------------------------------------------------❀

# %% [markdown]
# <h3><span style="color:khaki"><b>b) Variability between pairs</h3>
# <span style="color:red"><b>TODO: </span>How much different are the flactuation between diferent connections/electrode pairs. That means you need to see standard deviation across pairs not across time.
#
#
#
# Basically std tells us how much amplitude changes and how similar is it across data. When I need variablility of connectivity across time then we want to see how variable are el. pairs in time domain. When I want to see variability between electrodes themselfs then we do std across pairs for every time window
#
# <b> Interpretation
#
# >High variability → strong + weak connections coexist (some pairs comunicate strongly and some weakly)
# >
# >Low variability → everything looks similar (no strong special connections and network is homogeneus > but just the correlation)

# %%
variability = []

for matrix in connectivity:
    pair_vals = matrix[upper_indices]
    variability.append(np.std(pair_vals))
    
mid = len(variability)//2

fig, ax = plt.subplots(figsize=(10,3))
ax.plot(range(mid), variability[:mid], color="khaki", label="Low variability - eyes open")
ax.plot(range(mid, len(variability)), variability[mid:], color="powderblue", label="High variability - eyes closed")
plt.axvline(mid, color="red", linestyle='--', label ="condition switch")
plt.title("Variability across electrode pairs in time")
plt.ylabel("How similar are electrode pairs")
plt.xlabel("Over Time")
plt.legend()
plt.show()

print("You can see that at the end, the variability goes significantly down, that means that fluctuatuon between \nelectrode pairs becomes more similar than at the begining with the eyes closed")
# Out:
# You can see that at the end, the variability goes significantly down, that means that fluctuatuon between
# electrode pairs becomes more similar than at the begining with the eyes closed

# %% [markdown]
# <h3><span style="color:lightsteelblue"><b>d) Top 10 most changing pairs</h3>
# <span style="color:red"><b>TODO: </span> Which electrode pairs fluctuate the most over time? Use standard deviation across time in pair
#
# >Large std → wild movement
# >
# >Small std → stable connection

# %%
data_sample = "C01"
path = "./Corr_matrices/" + data_sample + "/"
files = sorted([f for f in os.listdir(path) if f.endswith("npy")])

matrices = []

for file in files:
    matrix = np.load(path + file)
    matrices.append(matrix)

connectivity = np.stack(matrices) # TIME, MATRIX
upper_indices = np.triu_indices(connectivity.shape[1], k=1)

pair_time_series = []

for i, j in zip(*upper_indices):
    pair_time_series.append(connectivity[:, i, j])

pair_time_series = np.array(pair_time_series)
pair_std = np.std(pair_time_series, axis=1)

top10 = np.argsort(pair_std)[-10:][::-1]
for idx in top10:
    i = upper_indices[0][idx]
    j = upper_indices[1][idx]

    print(ch_names[i], ch_names[j], pair_std[idx])
idx = top10[0]

plt.plot(pair_time_series[idx], color="lightsteelblue")
plt.title(f"{ch_names[upper_indices[0][idx]]} - {ch_names[upper_indices[1][idx]]}")
plt.xlabel("Time window")
plt.ylabel("Connectivity")
plt.show()
# Out:
# TP8 P10 0.334275398970869
# TPP10h P10 0.330057038302005
# P10 TPP8h 0.32988020182222677
# P8 P10 0.3291789467077666
# P10 CPP6h 0.3219631264043768
# P6 P10 0.3219336218724442
# P10 TTP8h 0.31958221561241384
# CP6 P10 0.3194890107006426
# P10 CCP6h 0.3194290047296857
# T8 P10 0.3186111352508992

# %%
def spam():
    ica.plot_sensors(
        show_names=True,
        kind="topomap",
        sphere='auto')

# %% [markdown]
# <h3><span style="color:darkseagreen"><b>c) Cluster dynamics</h3>
# <span style="color:red"><b>TODO: </span>
# systematickz vybitat oblasti podle Z stredu a ty vznecham a vezmu nalevo a napravo
# 3d koordinaty channnelov popripadě liche a sude strany
# F jako frontal a P jako pariental -> A, F : anterior
# interior, pariental a occipital vzadu ATD ATD
#
# leva prava, predni zadni, krizove,
#
# čim větší mean tím pa spolu komunikují

# %%
spam()

# %% [markdown]
# <h4><span style="color:darkseagreen"><b>Key to EEG electrode definition</h4>
#
# brain is organised from front( anterior) to the back(posterior), left and right, up in median sagital plane is superior down is inferior, lastlz to the Central is medial and out is lateral.
#
# - PreFrontal : Fp
# - Frontal : F
# - Central : C
# - Temporal : T
# - Pariental : P
# - Occipital : O
#
# <b>Other combination:
#
# - Zero : Z on a middle sagittal plane
# - Right hemisphere : Even numbers
# - Left hemisphere : Odd numbers
# - Anterior: AF, AFF anteriol frontal to |fornto-central & centro-pariental| to pariental occipital: PO, POO
#   - Adds anterior frontal, frontocentral, centropariental and parietoocipital
# - Inferior x Inion: I
#
#
# <span style="color:darkseagreen"><b> Separation of clusters by:
#
# <b>Sagittal plane</b> : Fpz, AFz, Fz, FCz, Cz, CPz, Pz, POz, Oz, Iz
# - Odd to Even
#     - left ↔ left
#     - right ↔ right
#     - left ↔ right
#
# <b>Right temporal to left temporal</b> : T even and T odd
#
# <b>Horizontal row across the head </b>: T7, C5, C3, C1, Cz, C2, C4, C6, T8
# - Within region connectivity
#     - frontal ↔ frontal
#     - parietal ↔ parietal
#     - occipital ↔ occipital
# - Neighboring regions
#     - frontal ↔ central
#     - central ↔ parietal
#     - parietal ↔ occipital
# - Long-renge communication
#     - frontal ↔ parietal
#     - frontal ↔ occipital
#
# <h4><span style="color:darkseagreen"><b>Hemisphere connectivity</h4>

# %%
left = []
right = []
midline = []

for i, ch in enumerate(ch_names):

    digits = ''.join(c for c in ch if c.isdigit())

    if ch.endswith('z') or digits == "":
        midline.append(i)

    else:
        num = int(digits)

        if num % 2 == 0:
            right.append(i)
        else:
            left.append(i)

#print("Left hemisphere:", left[:])
#print("Right hemisphere:", right[:10])
#print("Midline:", midline)

mean_leftToLeft = []
std_leftToLeft = []
for matrix in connectivity:
    valid_pairs = matrix[np.ix_(left, left)]
    mean_leftToLeft.append(np.mean(valid_pairs))
    std_leftToLeft.append(np.std(valid_pairs))

mean_leftToRight = []
std_leftToRight = []
for matrix in connectivity:
    valid_pairs = matrix[np.ix_(left, right)]
    mean_leftToRight.append(np.mean(valid_pairs))
    std_leftToRight.append(np.std(valid_pairs))

mean_rightToRight = []
std_rightToRight = []
for matrix in connectivity:
    valid_pairs = matrix[np.ix_(right, right)]
    mean_rightToRight.append(np.mean(valid_pairs))
    std_rightToRight.append(np.std(valid_pairs))

def plotMeanStd(mean, std, typeC):
    fig, ax = plt.subplots(2, 1, figsize=(10,6), sharex=True)
    
    ax[0].plot(mean, label="Connectivity mean", color="darkseagreen")
    ax[0].set_ylabel("Mean connectivity")
    ax[0].set_title(f"Connectivity over time for {typeC}")
    ax[0].axvline(mid, color="palevioletred", linestyle='--', label ="condition switch")
    ax[0].legend(loc='upper left')
    
    ax[1].plot(std, label="Connectivity std", color="thistle")
    ax[1].set_xlabel("Time (10s window, 1s step)")
    ax[1].set_ylabel("Std connectivity")
    ax[1].axvline(mid, color="palevioletred", linestyle='--', label ="condition switch")
    ax[1].legend(loc='upper left')
    plt.tight_layout()
    plt.show()

plotMeanStd(mean_leftToLeft, std_leftToLeft, "left ↔ left")
plotMeanStd(mean_leftToRight, std_leftToRight, "left ↔ right")
plotMeanStd(mean_rightToRight, std_rightToRight, "right ↔ right")

spam()

# %% [markdown]
# <h4><span style="color:darkseagreen"><b>Neigboring region connectivity</h4>
#
# ![alt](./../data/ReferencePictures/brain-section-eeg.jpg)
#
# How to select these regions:
#
# Frontal: what contains frontal etc... but these region could be more specified
#
# Pick your fucking batttle I think... since there will be overlaps or missing electrodes
#
# AF3 → frontal
# FC1 → frontal + central
# CP1 → central + parietal
# PO3 → parietal + occipital

# %%
def region_connectivity(connectivity, regionA, regionB):

    values = []

    for matrix in connectivity:
        vals = matrix[np.ix_(regionA, regionB)]
        values.append(np.mean(vals))

    return np.array(values)
    
def plotMean(mean, typeC):
    plt.figure(figsize=(10,3))
    plt.plot(mean, label=typeC)
    plt.xlabel("Time (s)")
    plt.ylabel("Mean connectivity")
    plt.title("Region-to-region connectivity")
    plt.legend()
    plt.show()

central = [i for i,ch in enumerate(ch_names) if ch.startswith(("FC","C","CP"))]
parietal = [i for i,ch in enumerate(ch_names) if ch.startswith(("CP","P"))]
occipital = [i for i,ch in enumerate(ch_names) if ch.startswith(("PO","O","I"))]
temporal = [i for i,ch in enumerate(ch_names) if ch.startswith(("T","FT","TP","TTP","FFT"))]
frontal = [i for i,ch in enumerate(ch_names) if ch.startswith(("Fp","AF","F")) and i not in temporal]
reference = [i for i,ch in enumerate(ch_names) if ch.startswith(("M"))]   # M1 M2 mastoids

#Regions of brain
regions = {
    "Frontal": frontal,
    "Central": central,
    "Parietal": parietal,
    "Occipital": occipital,
    "Temporal": temporal,
    "Reference": reference
}

# automatically generate all within- and between-region pairs
region_pairs = {}
for nameA, regA in regions.items():
    for nameB, regB in regions.items():
        key = f"{nameA} ↔ {nameB}"
        region_pairs[key] = region_connectivity(connectivity, regA, regB)

# Plot all of them
for label, series in region_pairs.items():
    plotMean(series, label)
