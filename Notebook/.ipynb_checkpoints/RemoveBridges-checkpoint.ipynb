# %% [markdown]
# <h1><span style="color:thistle"><b>Tasks:</span></h1>
#
# <h3>Remove Bridges and Electrodes</h3>
#
# - With MNE dictionary code you have been send through mattermost.
# - What it is:
# Basically occurence of unwanted connection between distinct electrodes which results in trend of having the same fucking numbers. Issue is mostly in gel placement(too much). Gel functions like a conduction between top of the head and electrode sensor. When there is too much it spreads and ends up connecting with another electrodes, resulting in joining the signal of two or more electrodes into one, destroing the results.
# - Easiest solution to Bridges will be just removing connected electrodes alltogether.
# - Usefunction Compute_bridge_electrodes: gives back bridges index of electrodes and electric distance of electrode (the bigger the better, smaller delete)
# - U can use topomap to visualise removal of connected electrodes-Bridges
# - When you start
#       - use default value, then change the trashold for multiple results to compare >> use different names and dont delete them
#       - podivej se jeste na dve funkce downsample u dvojky abz to nahodou nezohlednovalo tzodstranene matic e
#
# Electrode plot topomap - koukni do mattermostu.
# 	Data musi mit shape number of channels
# 	koukni jestli se dá printit dva různý regionz v jedný hlavy
# start using raw (talk atar
#
# using plv instead of cross corelation
# 	corr is really blind to rest of the code
#
# like 100 sampling rate

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

import mne

# %% [markdown]
# <h1>EEG Electrode bridges</h1>
# <h2>Compute Electrical Distance Metric</h2>
#
# Electrical distance is the varriance of signals subtracted pairwise.
# Channels mirroring other electrodes almost exactly have very low electrical distance.
# We will look for pairs that have ed almost zero
#
# This func. is supposed to run on short time period of data that is not at the beginning due to the gel settlement ove time. SO using the last segment of the data will give the most conservative estimate.

# %%
path = './../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif'
subject = mne.io.read_raw_fif(path, preload=True)
montage = mne.channels.make_standard_montage("standard_1005")
subject.set_montage(montage)

#raw = subject.copy().set_eeg_reference('average', projection=False) # that shit hit the same
print(f"Computing electrode bridges for subject {path}")
#raw_data[path] = subject
#ed_data[path] = mne.preprocessing.compute_bridged_electrodes(subject)
bridged_idx, ed_matrix = mne.preprocessing.compute_bridged_electrodes(subject)
# Out:
# Opening raw data file ./../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif...
#     Range : 0 ... 4287999 =      0.000 ...   536.000 secs
# Ready.
# Opening raw data file /home/manka-roblik/AnalysisBooredEEG/Notebook/../data/C01/C01_2024-11-16_10-44-51_RS_before_ica-1.fif...
#     Range : 4288000 ... 4807672 =    536.000 ...   600.959 secs
# Ready.
# Reading 0 ... 4807672  =      0.000 ...   600.959 secs...
# /tmp/ipykernel_37026/3425097131.py:2: RuntimeWarning: This filename (./../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   subject = mne.io.read_raw_fif(path, preload=True)
# Computing electrode bridges for subject ./../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif
# Local minimum 9.324623354565544 found
# Bridge detected between Fp1 and Fpz
# Bridge detected between Fp1 and Fp2
# Bridge detected between Fp1 and F7
# Bridge detected between Fp1 and F8
# Bridge detected between Fp1 and FC5
# Bridge detected between Fp1 and AF7
# Bridge detected between Fp1 and AF3
# Bridge detected between Fp1 and F5
# Bridge detected between Fp1 and C5
# Bridge detected between Fp1 and FT7
# Bridge detected between Fp1 and AFF1
# Bridge detected between Fp1 and AFz
# Bridge detected between Fp1 and FFC5h
# Bridge detected between Fp1 and FCC5h
# Bridge detected between Fp1 and CCP5h
# Bridge detected between Fp1 and AFp3h
# Bridge detected between Fp1 and AFp4h
# Bridge detected between Fp1 and AFF5h
# Bridge detected between Fp1 and FFT7h
# Bridge detected between Fp1 and FFT8h
# Bridge detected between Fp1 and FTT7h
# Bridge detected between Fp1 and TTP7h
# Bridge detected between Fpz and Fp2
# Bridge detected between Fpz and F7
# Bridge detected between Fpz and FC5
# Bridge detected between Fpz and AF3
# Bridge detected between Fpz and F5
# Bridge detected between Fpz and AFz
# Bridge detected between Fpz and FFC5h
# Bridge detected between Fpz and FCC5h
# Bridge detected between Fpz and AFp3h
# Bridge detected between Fpz and AFp4h
# Bridge detected between Fpz and AFF5h
# Bridge detected between Fpz and FFT7h
# Bridge detected between Fp2 and F7
# Bridge detected between Fp2 and Fz
# Bridge detected between Fp2 and F4
# Bridge detected between Fp2 and F8
# Bridge detected between Fp2 and FC5
# Bridge detected between Fp2 and FC6
# Bridge detected between Fp2 and T7
# Bridge detected between Fp2 and AF7
# Bridge detected between Fp2 and AF3
# Bridge detected between Fp2 and AF4
# Bridge detected between Fp2 and AF8
# Bridge detected between Fp2 and F5
# Bridge detected between Fp2 and F2
# Bridge detected between Fp2 and F6
# Bridge detected between Fp2 and FC4
# Bridge detected between Fp2 and C5
# Bridge detected between Fp2 and FT7
# Bridge detected between Fp2 and AFF1
# Bridge detected between Fp2 and AFz
# Bridge detected between Fp2 and AFF2
# Bridge detected between Fp2 and FFC5h
# Bridge detected between Fp2 and FFC4h
# Bridge detected between Fp2 and FFC6h
# Bridge detected between Fp2 and FCC5h
# Bridge detected between Fp2 and FCC6h
# Bridge detected between Fp2 and CCP5h
# Bridge detected between Fp2 and AFp3h
# Bridge detected between Fp2 and AFp4h
# Bridge detected between Fp2 and AFF5h
# Bridge detected between Fp2 and AFF6h
# Bridge detected between Fp2 and FFT7h
# Bridge detected between Fp2 and FFC2h
# Bridge detected between Fp2 and FFT8h
# Bridge detected between Fp2 and FTT7h
# Bridge detected between Fp2 and TTP7h
# Bridge detected between F7 and F3
# Bridge detected between F7 and Fz
# Bridge detected between F7 and F4
# Bridge detected between F7 and F8
# Bridge detected between F7 and FC5
# Bridge detected between F7 and FC1
# Bridge detected between F7 and FC2
# Bridge detected between F7 and FC6
# Bridge detected between F7 and T7
# Bridge detected between F7 and C3
# Bridge detected between F7 and C4
# Bridge detected between F7 and CP5
# Bridge detected between F7 and CP1
# Bridge detected between F7 and CP2
# Bridge detected between F7 and P3
# Bridge detected between F7 and Pz
# Bridge detected between F7 and AF7
# Bridge detected between F7 and AF3
# Bridge detected between F7 and AF4
# Bridge detected between F7 and AF8
# Bridge detected between F7 and F5
# Bridge detected between F7 and F1
# Bridge detected between F7 and F2
# Bridge detected between F7 and F6
# Bridge detected between F7 and FC3
# Bridge detected between F7 and FCz
# Bridge detected between F7 and FC4
# Bridge detected between F7 and C5
# Bridge detected between F7 and C1
# Bridge detected between F7 and C2
# Bridge detected between F7 and CP4
# Bridge detected between F7 and P1
# Bridge detected between F7 and P2
# Bridge detected between F7 and FT7
# Bridge detected between F7 and AFF1
# Bridge detected between F7 and AFz
# Bridge detected between F7 and AFF2
# Bridge detected between F7 and FFC5h
# Bridge detected between F7 and FFC3h
# Bridge detected between F7 and FFC4h
# Bridge detected between F7 and FFC6h
# Bridge detected between F7 and FCC5h
# Bridge detected between F7 and FCC3h
# Bridge detected between F7 and FCC4h
# Bridge detected between F7 and FCC6h
# Bridge detected between F7 and CCP5h
# Bridge detected between F7 and CCP3h
# Bridge detected between F7 and CCP4h
# Bridge detected between F7 and CPP3h
# Bridge detected between F7 and CPP4h
# Bridge detected between F7 and PPO2
# Bridge detected between F7 and AFp3h
# Bridge detected between F7 and AFp4h
# Bridge detected between F7 and AFF5h
# Bridge detected between F7 and AFF6h
# Bridge detected between F7 and FFT7h
# Bridge detected between F7 and FFC1h
# Bridge detected between F7 and FFC2h
# Bridge detected between F7 and FFT8h
# Bridge detected between F7 and FTT7h
# Bridge detected between F7 and FCC1h
# Bridge detected between F7 and FCC2h
# Bridge detected between F7 and TTP7h
# Bridge detected between F7 and CCP1h
# Bridge detected between F7 and CCP2h
# Bridge detected between F7 and CPP1h
# Bridge detected between F7 and CPP2h
# Bridge detected between F3 and Fz
# Bridge detected between F3 and F4
# Bridge detected between F3 and FC5
# Bridge detected between F3 and FC1
# Bridge detected between F3 and FC2
# Bridge detected between F3 and FC6
# Bridge detected between F3 and C3
# Bridge detected between F3 and Cz
# Bridge detected between F3 and C4
# Bridge detected between F3 and CP1
# Bridge detected between F3 and CP2
# Bridge detected between F3 and P3
# Bridge detected between F3 and Pz
# Bridge detected between F3 and AF3
# Bridge detected between F3 and AF4
# Bridge detected between F3 and F5
# Bridge detected between F3 and F1
# Bridge detected between F3 and F2
# Bridge detected between F3 and F6
# Bridge detected between F3 and FC3
# Bridge detected between F3 and FCz
# Bridge detected between F3 and FC4
# Bridge detected between F3 and C1
# Bridge detected between F3 and C2
# Bridge detected between F3 and CP4
# Bridge detected between F3 and P1
# Bridge detected between F3 and P2
# Bridge detected between F3 and AFF1
# Bridge detected between F3 and AFz
# Bridge detected between F3 and AFF2
# Bridge detected between F3 and FFC5h
# Bridge detected between F3 and FFC3h
# Bridge detected between F3 and FFC4h
# Bridge detected between F3 and FFC6h
# Bridge detected between F3 and FCC5h
# Bridge detected between F3 and FCC3h
# Bridge detected between F3 and FCC4h
# Bridge detected between F3 and FCC6h
# Bridge detected between F3 and CCP3h
# Bridge detected between F3 and CCP4h
# Bridge detected between F3 and CPP3h
# Bridge detected between F3 and CPP4h
# Bridge detected between F3 and PPO2
# Bridge detected between F3 and AFp3h
# Bridge detected between F3 and AFp4h
# Bridge detected between F3 and AFF5h
# Bridge detected between F3 and AFF6h
# Bridge detected between F3 and FFT7h
# Bridge detected between F3 and FFC1h
# Bridge detected between F3 and FFC2h
# Bridge detected between F3 and FCC1h
# Bridge detected between F3 and FCC2h
# Bridge detected between F3 and CCP1h
# Bridge detected between F3 and CCP2h
# Bridge detected between F3 and CPP1h
# Bridge detected between F3 and CPP2h
# Bridge detected between Fz and F4
# Bridge detected between Fz and FC5
# Bridge detected between Fz and FC1
# Bridge detected between Fz and FC2
# Bridge detected between Fz and FC6
# Bridge detected between Fz and C3
# Bridge detected between Fz and Cz
# Bridge detected between Fz and C4
# Bridge detected between Fz and CP1
# Bridge detected between Fz and CP2
# Bridge detected between Fz and P3
# Bridge detected between Fz and Pz
# Bridge detected between Fz and AF3
# Bridge detected between Fz and AF4
# Bridge detected between Fz and F5
# Bridge detected between Fz and F1
# Bridge detected between Fz and F2
# Bridge detected between Fz and F6
# Bridge detected between Fz and FC3
# Bridge detected between Fz and FCz
# Bridge detected between Fz and FC4
# Bridge detected between Fz and C1
# Bridge detected between Fz and C2
# Bridge detected between Fz and CP3
# Bridge detected between Fz and CP4
# Bridge detected between Fz and P1
# Bridge detected between Fz and P2
# Bridge detected between Fz and AFF1
# Bridge detected between Fz and AFz
# Bridge detected between Fz and AFF2
# Bridge detected between Fz and FFC5h
# Bridge detected between Fz and FFC3h
# Bridge detected between Fz and FFC4h
# Bridge detected between Fz and FFC6h
# Bridge detected between Fz and FCC5h
# Bridge detected between Fz and FCC3h
# Bridge detected between Fz and FCC4h
# Bridge detected between Fz and FCC6h
# Bridge detected between Fz and CCP3h
# Bridge detected between Fz and CCP4h
# Bridge detected between Fz and CPP3h
# Bridge detected between Fz and CPP4h
# Bridge detected between Fz and PPO2
# Bridge detected between Fz and AFp3h
# Bridge detected between Fz and AFp4h
# Bridge detected between Fz and AFF5h
# Bridge detected between Fz and AFF6h
# Bridge detected between Fz and FFT7h
# Bridge detected between Fz and FFC1h
# Bridge detected between Fz and FFC2h
# Bridge detected between Fz and FCC1h
# Bridge detected between Fz and FCC2h
# Bridge detected between Fz and CCP1h
# Bridge detected between Fz and CCP2h
# Bridge detected between Fz and CPP1h
# Bridge detected between Fz and CPP2h
# Bridge detected between F4 and FC5
# Bridge detected between F4 and FC1
# Bridge detected between F4 and FC2
# Bridge detected between F4 and FC6
# Bridge detected between F4 and C3
# Bridge detected between F4 and Cz
# Bridge detected between F4 and C4
# Bridge detected between F4 and CP1
# Bridge detected between F4 and CP2
# Bridge detected between F4 and P3
# Bridge detected between F4 and Pz
# Bridge detected between F4 and AF3
# Bridge detected between F4 and AF4
# Bridge detected between F4 and F5
# Bridge detected between F4 and F1
# Bridge detected between F4 and F2
# Bridge detected between F4 and F6
# Bridge detected between F4 and FC3
# Bridge detected between F4 and FCz
# Bridge detected between F4 and FC4
# Bridge detected between F4 and C1
# Bridge detected between F4 and C2
# Bridge detected between F4 and CP3
# Bridge detected between F4 and CP4
# Bridge detected between F4 and P1
# Bridge detected between F4 and P2
# Bridge detected between F4 and AFF1
# Bridge detected between F4 and AFz
# Bridge detected between F4 and AFF2
# Bridge detected between F4 and FFC5h
# Bridge detected between F4 and FFC3h
# Bridge detected between F4 and FFC4h
# Bridge detected between F4 and FFC6h
# Bridge detected between F4 and FCC5h
# Bridge detected between F4 and FCC3h
# Bridge detected between F4 and FCC4h
# Bridge detected between F4 and FCC6h
# Bridge detected between F4 and CCP3h
# Bridge detected between F4 and CCP4h
# Bridge detected between F4 and CPP3h
# Bridge detected between F4 and CPP4h
# Bridge detected between F4 and PPO2
# Bridge detected between F4 and AFp3h
# Bridge detected between F4 and AFp4h
# Bridge detected between F4 and AFF5h
# Bridge detected between F4 and AFF6h
# Bridge detected between F4 and FFT7h
# Bridge detected between F4 and FFC1h
# Bridge detected between F4 and FFC2h
# Bridge detected between F4 and FCC1h
# Bridge detected between F4 and FCC2h
# Bridge detected between F4 and CCP1h
# Bridge detected between F4 and CCP2h
# Bridge detected between F4 and CPP1h
# Bridge detected between F4 and CPP2h
# Bridge detected between F8 and FC5
# Bridge detected between F8 and AF7
# Bridge detected between F8 and AF3
# Bridge detected between F8 and F5
# Bridge detected between F8 and FFC5h
# Bridge detected between F8 and FCC5h
# Bridge detected between F8 and AFp3h
# Bridge detected between F8 and AFp4h
# Bridge detected between F8 and AFF5h
# Bridge detected between F8 and FFT7h
# Bridge detected between F8 and FFT8h
# Bridge detected between FC5 and FC1
# Bridge detected between FC5 and FC2
# Bridge detected between FC5 and FC6
# Bridge detected between FC5 and T7
# Bridge detected between FC5 and C3
# Bridge detected between FC5 and C4
# Bridge detected between FC5 and CP5
# Bridge detected between FC5 and CP1
# Bridge detected between FC5 and CP2
# Bridge detected between FC5 and P3
# Bridge detected between FC5 and Pz
# Bridge detected between FC5 and AF7
# Bridge detected between FC5 and AF3
# Bridge detected between FC5 and AF4
# Bridge detected between FC5 and AF8
# Bridge detected between FC5 and F5
# Bridge detected between FC5 and F1
# Bridge detected between FC5 and F2
# Bridge detected between FC5 and F6
# Bridge detected between FC5 and FC3
# Bridge detected between FC5 and FCz
# Bridge detected between FC5 and FC4
# Bridge detected between FC5 and C5
# Bridge detected between FC5 and C1
# Bridge detected between FC5 and C2
# Bridge detected between FC5 and CP4
# Bridge detected between FC5 and P1
# Bridge detected between FC5 and P2
# Bridge detected between FC5 and FT7
# Bridge detected between FC5 and AFF1
# Bridge detected between FC5 and AFz
# Bridge detected between FC5 and AFF2
# Bridge detected between FC5 and FFC5h
# Bridge detected between FC5 and FFC3h
# Bridge detected between FC5 and FFC4h
# Bridge detected between FC5 and FFC6h
# Bridge detected between FC5 and FCC5h
# Bridge detected between FC5 and FCC3h
# Bridge detected between FC5 and FCC4h
# Bridge detected between FC5 and FCC6h
# Bridge detected between FC5 and CCP5h
# Bridge detected between FC5 and CCP3h
# Bridge detected between FC5 and CCP4h
# Bridge detected between FC5 and CPP3h
# Bridge detected between FC5 and CPP4h
# Bridge detected between FC5 and PPO2
# Bridge detected between FC5 and AFp3h
# Bridge detected between FC5 and AFp4h
# Bridge detected between FC5 and AFF5h
# Bridge detected between FC5 and AFF6h
# Bridge detected between FC5 and FFT7h
# Bridge detected between FC5 and FFC1h
# Bridge detected between FC5 and FFC2h
# Bridge detected between FC5 and FFT8h
# Bridge detected between FC5 and FTT7h
# Bridge detected between FC5 and FCC1h
# Bridge detected between FC5 and FCC2h
# Bridge detected between FC5 and TTP7h
# Bridge detected between FC5 and CCP1h
# Bridge detected between FC5 and CCP2h
# Bridge detected between FC5 and CPP1h
# Bridge detected between FC5 and CPP2h
# Bridge detected between FC1 and FC2
# Bridge detected between FC1 and FC6
# Bridge detected between FC1 and C3
# Bridge detected between FC1 and Cz
# Bridge detected between FC1 and C4
# Bridge detected between FC1 and CP1
# Bridge detected between FC1 and CP2
# Bridge detected between FC1 and P3
# Bridge detected between FC1 and Pz
# Bridge detected between FC1 and AF3
# Bridge detected between FC1 and AF4
# Bridge detected between FC1 and F5
# Bridge detected between FC1 and F1
# Bridge detected between FC1 and F2
# Bridge detected between FC1 and F6
# Bridge detected between FC1 and FC3
# Bridge detected between FC1 and FCz
# Bridge detected between FC1 and FC4
# Bridge detected between FC1 and C1
# Bridge detected between FC1 and C2
# Bridge detected between FC1 and CP4
# Bridge detected between FC1 and P1
# Bridge detected between FC1 and P2
# Bridge detected between FC1 and AFF1
# Bridge detected between FC1 and AFz
# Bridge detected between FC1 and AFF2
# Bridge detected between FC1 and FFC5h
# Bridge detected between FC1 and FFC3h
# Bridge detected between FC1 and FFC4h
# Bridge detected between FC1 and FFC6h
# Bridge detected between FC1 and FCC5h
# Bridge detected between FC1 and FCC3h
# Bridge detected between FC1 and FCC4h
# Bridge detected between FC1 and FCC6h
# Bridge detected between FC1 and CCP3h
# Bridge detected between FC1 and CCP4h
# Bridge detected between FC1 and CPP3h
# Bridge detected between FC1 and CPP4h
# Bridge detected between FC1 and PPO2
# Bridge detected between FC1 and AFp3h
# Bridge detected between FC1 and AFp4h
# Bridge detected between FC1 and AFF5h
# Bridge detected between FC1 and AFF6h
# Bridge detected between FC1 and FFT7h
# Bridge detected between FC1 and FFC1h
# Bridge detected between FC1 and FFC2h
# Bridge detected between FC1 and FCC1h
# Bridge detected between FC1 and FCC2h
# Bridge detected between FC1 and CCP1h
# Bridge detected between FC1 and CCP2h
# Bridge detected between FC1 and CPP1h
# Bridge detected between FC1 and CPP2h
# Bridge detected between FC2 and FC6
# Bridge detected between FC2 and C3
# Bridge detected between FC2 and Cz
# Bridge detected between FC2 and C4
# Bridge detected between FC2 and CP1
# Bridge detected between FC2 and CP2
# Bridge detected between FC2 and P3
# Bridge detected between FC2 and Pz
# Bridge detected between FC2 and AF3
# Bridge detected between FC2 and AF4
# Bridge detected between FC2 and F5
# Bridge detected between FC2 and F1
# Bridge detected between FC2 and F2
# Bridge detected between FC2 and F6
# Bridge detected between FC2 and FC3
# Bridge detected between FC2 and FCz
# Bridge detected between FC2 and FC4
# Bridge detected between FC2 and C1
# Bridge detected between FC2 and C2
# Bridge detected between FC2 and CP3
# Bridge detected between FC2 and CP4
# Bridge detected between FC2 and P1
# Bridge detected between FC2 and P2
# Bridge detected between FC2 and AFF1
# Bridge detected between FC2 and AFz
# Bridge detected between FC2 and AFF2
# Bridge detected between FC2 and FFC5h
# Bridge detected between FC2 and FFC3h
# Bridge detected between FC2 and FFC4h
# Bridge detected between FC2 and FFC6h
# Bridge detected between FC2 and FCC5h
# Bridge detected between FC2 and FCC3h
# Bridge detected between FC2 and FCC4h
# Bridge detected between FC2 and FCC6h
# Bridge detected between FC2 and CCP3h
# Bridge detected between FC2 and CCP4h
# Bridge detected between FC2 and CPP3h
# Bridge detected between FC2 and CPP4h
# Bridge detected between FC2 and PPO2
# Bridge detected between FC2 and AFp3h
# Bridge detected between FC2 and AFp4h
# Bridge detected between FC2 and AFF5h
# Bridge detected between FC2 and AFF6h
# Bridge detected between FC2 and FFT7h
# Bridge detected between FC2 and FFC1h
# Bridge detected between FC2 and FFC2h
# Bridge detected between FC2 and FCC1h
# Bridge detected between FC2 and FCC2h
# Bridge detected between FC2 and CCP1h
# Bridge detected between FC2 and CCP2h
# Bridge detected between FC2 and CPP1h
# Bridge detected between FC2 and CPP2h
# Bridge detected between FC6 and C3
# Bridge detected between FC6 and Cz
# Bridge detected between FC6 and C4
# Bridge detected between FC6 and CP1
# Bridge detected between FC6 and CP2
# Bridge detected between FC6 and P3
# Bridge detected between FC6 and Pz
# Bridge detected between FC6 and AF3
# Bridge detected between FC6 and AF4
# Bridge detected between FC6 and F5
# Bridge detected between FC6 and F1
# Bridge detected between FC6 and F2
# Bridge detected between FC6 and F6
# Bridge detected between FC6 and FC3
# Bridge detected between FC6 and FCz
# Bridge detected between FC6 and FC4
# Bridge detected between FC6 and C1
# Bridge detected between FC6 and C2
# Bridge detected between FC6 and CP3
# Bridge detected between FC6 and CP4
# Bridge detected between FC6 and P1
# Bridge detected between FC6 and P2
# Bridge detected between FC6 and AFF1
# Bridge detected between FC6 and AFz
# Bridge detected between FC6 and AFF2
# Bridge detected between FC6 and FFC5h
# Bridge detected between FC6 and FFC3h
# Bridge detected between FC6 and FFC4h
# Bridge detected between FC6 and FFC6h
# Bridge detected between FC6 and FCC5h
# Bridge detected between FC6 and FCC3h
# Bridge detected between FC6 and FCC4h
# Bridge detected between FC6 and FCC6h
# Bridge detected between FC6 and CCP3h
# Bridge detected between FC6 and CCP4h
# Bridge detected between FC6 and CPP3h
# Bridge detected between FC6 and CPP4h
# Bridge detected between FC6 and PPO2
# Bridge detected between FC6 and AFp3h
# Bridge detected between FC6 and AFp4h
# Bridge detected between FC6 and AFF5h
# Bridge detected between FC6 and AFF6h
# Bridge detected between FC6 and FFT7h
# Bridge detected between FC6 and FFC1h
# Bridge detected between FC6 and FFC2h
# Bridge detected between FC6 and FCC1h
# Bridge detected between FC6 and FCC2h
# Bridge detected between FC6 and CCP1h
# Bridge detected between FC6 and CCP2h
# Bridge detected between FC6 and CPP1h
# Bridge detected between FC6 and CPP2h
# Bridge detected between T7 and CP5
# Bridge detected between T7 and AF3
# Bridge detected between T7 and F5
# Bridge detected between T7 and C5
# Bridge detected between T7 and FT7
# Bridge detected between T7 and FT9
# Bridge detected between T7 and FFC5h
# Bridge detected between T7 and FCC5h
# Bridge detected between T7 and CCP5h
# Bridge detected between T7 and AFp3h
# Bridge detected between T7 and AFF5h
# Bridge detected between T7 and FFT7h
# Bridge detected between T7 and FTT9h
# Bridge detected between T7 and FTT7h
# Bridge detected between T7 and TTP7h
# Bridge detected between C3 and Cz
# Bridge detected between C3 and C4
# Bridge detected between C3 and CP1
# Bridge detected between C3 and CP2
# Bridge detected between C3 and P3
# Bridge detected between C3 and Pz
# Bridge detected between C3 and AF3
# Bridge detected between C3 and AF4
# Bridge detected between C3 and F5
# Bridge detected between C3 and F1
# Bridge detected between C3 and F2
# Bridge detected between C3 and F6
# Bridge detected between C3 and FC3
# Bridge detected between C3 and FCz
# Bridge detected between C3 and FC4
# Bridge detected between C3 and C1
# Bridge detected between C3 and C2
# Bridge detected between C3 and CP3
# Bridge detected between C3 and CP4
# Bridge detected between C3 and P1
# Bridge detected between C3 and P2
# Bridge detected between C3 and AFF1
# Bridge detected between C3 and AFz
# Bridge detected between C3 and AFF2
# Bridge detected between C3 and FFC5h
# Bridge detected between C3 and FFC3h
# Bridge detected between C3 and FFC4h
# Bridge detected between C3 and FFC6h
# Bridge detected between C3 and FCC5h
# Bridge detected between C3 and FCC3h
# Bridge detected between C3 and FCC4h
# Bridge detected between C3 and FCC6h
# Bridge detected between C3 and CCP3h
# Bridge detected between C3 and CCP4h
# Bridge detected between C3 and CPP3h
# Bridge detected between C3 and CPP4h
# Bridge detected between C3 and PPO2
# Bridge detected between C3 and AFp3h
# Bridge detected between C3 and AFp4h
# Bridge detected between C3 and AFF5h
# Bridge detected between C3 and AFF6h
# Bridge detected between C3 and FFT7h
# Bridge detected between C3 and FFC1h
# Bridge detected between C3 and FFC2h
# Bridge detected between C3 and FCC1h
# Bridge detected between C3 and FCC2h
# Bridge detected between C3 and CCP1h
# Bridge detected between C3 and CCP2h
# Bridge detected between C3 and CPP1h
# Bridge detected between C3 and CPP2h
# Bridge detected between Cz and C4
# Bridge detected between Cz and CP1
# Bridge detected between Cz and CP2
# Bridge detected between Cz and P3
# Bridge detected between Cz and Pz
# Bridge detected between Cz and AF4
# Bridge detected between Cz and F1
# Bridge detected between Cz and F2
# Bridge detected between Cz and F6
# Bridge detected between Cz and FC3
# Bridge detected between Cz and FCz
# Bridge detected between Cz and FC4
# Bridge detected between Cz and C1
# Bridge detected between Cz and C2
# Bridge detected between Cz and CP4
# Bridge detected between Cz and P1
# Bridge detected between Cz and P2
# Bridge detected between Cz and AFF1
# Bridge detected between Cz and AFF2
# Bridge detected between Cz and FFC3h
# Bridge detected between Cz and FFC4h
# Bridge detected between Cz and FFC6h
# Bridge detected between Cz and FCC3h
# Bridge detected between Cz and FCC4h
# Bridge detected between Cz and FCC6h
# Bridge detected between Cz and CCP3h
# Bridge detected between Cz and CCP4h
# Bridge detected between Cz and CPP3h
# Bridge detected between Cz and CPP4h
# Bridge detected between Cz and PPO2
# Bridge detected between Cz and AFF6h
# Bridge detected between Cz and FFC1h
# Bridge detected between Cz and FFC2h
# Bridge detected between Cz and FCC1h
# Bridge detected between Cz and FCC2h
# Bridge detected between Cz and CCP1h
# Bridge detected between Cz and CCP2h
# Bridge detected between Cz and CPP1h
# Bridge detected between Cz and CPP2h
# Bridge detected between C4 and CP1
# Bridge detected between C4 and CP2
# Bridge detected between C4 and P3
# Bridge detected between C4 and Pz
# Bridge detected between C4 and AF3
# Bridge detected between C4 and AF4
# Bridge detected between C4 and F5
# Bridge detected between C4 and F1
# Bridge detected between C4 and F2
# Bridge detected between C4 and F6
# Bridge detected between C4 and FC3
# Bridge detected between C4 and FCz
# Bridge detected between C4 and FC4
# Bridge detected between C4 and C1
# Bridge detected between C4 and C2
# Bridge detected between C4 and CP3
# Bridge detected between C4 and CP4
# Bridge detected between C4 and P1
# Bridge detected between C4 and P2
# Bridge detected between C4 and AFF1
# Bridge detected between C4 and AFz
# Bridge detected between C4 and AFF2
# Bridge detected between C4 and FFC5h
# Bridge detected between C4 and FFC3h
# Bridge detected between C4 and FFC4h
# Bridge detected between C4 and FFC6h
# Bridge detected between C4 and FCC5h
# Bridge detected between C4 and FCC3h
# Bridge detected between C4 and FCC4h
# Bridge detected between C4 and FCC6h
# Bridge detected between C4 and CCP3h
# Bridge detected between C4 and CCP4h
# Bridge detected between C4 and CPP3h
# Bridge detected between C4 and CPP4h
# Bridge detected between C4 and PPO2
# Bridge detected between C4 and AFp3h
# Bridge detected between C4 and AFp4h
# Bridge detected between C4 and AFF5h
# Bridge detected between C4 and AFF6h
# Bridge detected between C4 and FFT7h
# Bridge detected between C4 and FFC1h
# Bridge detected between C4 and FFC2h
# Bridge detected between C4 and FCC1h
# Bridge detected between C4 and FCC2h
# Bridge detected between C4 and CCP1h
# Bridge detected between C4 and CCP2h
# Bridge detected between C4 and CPP1h
# Bridge detected between C4 and CPP2h
# Bridge detected between T8 and CP6
# Bridge detected between T8 and P4
# Bridge detected between T8 and P8
# Bridge detected between T8 and P6
# Bridge detected between T8 and PO4
# Bridge detected between T8 and TP8
# Bridge detected between T8 and PO8
# Bridge detected between T8 and TPP10h
# Bridge detected between T8 and PO10
# Bridge detected between T8 and CCP6h
# Bridge detected between T8 and CPP6h
# Bridge detected between T8 and TTP8h
# Bridge detected between T8 and TPP8h
# Bridge detected between T8 and PPO6h
# Bridge detected between T8 and PPO10h
# Bridge detected between CP5 and AF3
# Bridge detected between CP5 and F5
# Bridge detected between CP5 and C5
# Bridge detected between CP5 and CP3
# Bridge detected between CP5 and FT7
# Bridge detected between CP5 and FFC5h
# Bridge detected between CP5 and FCC5h
# Bridge detected between CP5 and CCP5h
# Bridge detected between CP5 and AFp3h
# Bridge detected between CP5 and AFF5h
# Bridge detected between CP5 and FFT7h
# Bridge detected between CP5 and FTT7h
# Bridge detected between CP5 and TTP7h
# Bridge detected between CP1 and CP2
# Bridge detected between CP1 and P3
# Bridge detected between CP1 and Pz
# Bridge detected between CP1 and AF3
# Bridge detected between CP1 and AF4
# Bridge detected between CP1 and F5
# Bridge detected between CP1 and F1
# Bridge detected between CP1 and F2
# Bridge detected between CP1 and F6
# Bridge detected between CP1 and FC3
# Bridge detected between CP1 and FCz
# Bridge detected between CP1 and FC4
# Bridge detected between CP1 and C1
# Bridge detected between CP1 and C2
# Bridge detected between CP1 and CP3
# Bridge detected between CP1 and CP4
# Bridge detected between CP1 and P1
# Bridge detected between CP1 and P2
# Bridge detected between CP1 and AFF1
# Bridge detected between CP1 and AFz
# Bridge detected between CP1 and AFF2
# Bridge detected between CP1 and FFC5h
# Bridge detected between CP1 and FFC3h
# Bridge detected between CP1 and FFC4h
# Bridge detected between CP1 and FFC6h
# Bridge detected between CP1 and FCC5h
# Bridge detected between CP1 and FCC3h
# Bridge detected between CP1 and FCC4h
# Bridge detected between CP1 and FCC6h
# Bridge detected between CP1 and CCP3h
# Bridge detected between CP1 and CCP4h
# Bridge detected between CP1 and CPP3h
# Bridge detected between CP1 and CPP4h
# Bridge detected between CP1 and PPO2
# Bridge detected between CP1 and AFp3h
# Bridge detected between CP1 and AFp4h
# Bridge detected between CP1 and AFF5h
# Bridge detected between CP1 and AFF6h
# Bridge detected between CP1 and FFT7h
# Bridge detected between CP1 and FFC1h
# Bridge detected between CP1 and FFC2h
# Bridge detected between CP1 and FCC1h
# Bridge detected between CP1 and FCC2h
# Bridge detected between CP1 and CCP1h
# Bridge detected between CP1 and CCP2h
# Bridge detected between CP1 and CPP1h
# Bridge detected between CP1 and CPP2h
# Bridge detected between CP2 and P3
# Bridge detected between CP2 and Pz
# Bridge detected between CP2 and AF3
# Bridge detected between CP2 and AF4
# Bridge detected between CP2 and F5
# Bridge detected between CP2 and F1
# Bridge detected between CP2 and F2
# Bridge detected between CP2 and F6
# Bridge detected between CP2 and FC3
# Bridge detected between CP2 and FCz
# Bridge detected between CP2 and FC4
# Bridge detected between CP2 and C1
# Bridge detected between CP2 and C2
# Bridge detected between CP2 and CP3
# Bridge detected between CP2 and CP4
# Bridge detected between CP2 and P1
# Bridge detected between CP2 and P2
# Bridge detected between CP2 and AFF1
# Bridge detected between CP2 and AFz
# Bridge detected between CP2 and AFF2
# Bridge detected between CP2 and FFC5h
# Bridge detected between CP2 and FFC3h
# Bridge detected between CP2 and FFC4h
# Bridge detected between CP2 and FFC6h
# Bridge detected between CP2 and FCC5h
# Bridge detected between CP2 and FCC3h
# Bridge detected between CP2 and FCC4h
# Bridge detected between CP2 and FCC6h
# Bridge detected between CP2 and CCP3h
# Bridge detected between CP2 and CCP4h
# Bridge detected between CP2 and CPP3h
# Bridge detected between CP2 and CPP4h
# Bridge detected between CP2 and PPO2
# Bridge detected between CP2 and AFp3h
# Bridge detected between CP2 and AFp4h
# Bridge detected between CP2 and AFF5h
# Bridge detected between CP2 and AFF6h
# Bridge detected between CP2 and FFT7h
# Bridge detected between CP2 and FFC1h
# Bridge detected between CP2 and FFC2h
# Bridge detected between CP2 and FCC1h
# Bridge detected between CP2 and FCC2h
# Bridge detected between CP2 and CCP1h
# Bridge detected between CP2 and CCP2h
# Bridge detected between CP2 and CPP1h
# Bridge detected between CP2 and CPP2h
# Bridge detected between CP6 and P4
# Bridge detected between CP6 and P8
# Bridge detected between CP6 and P6
# Bridge detected between CP6 and PO4
# Bridge detected between CP6 and TP8
# Bridge detected between CP6 and PO8
# Bridge detected between CP6 and TPP10h
# Bridge detected between CP6 and PO10
# Bridge detected between CP6 and CCP6h
# Bridge detected between CP6 and CPP6h
# Bridge detected between CP6 and TTP8h
# Bridge detected between CP6 and TPP8h
# Bridge detected between CP6 and PPO6h
# Bridge detected between CP6 and PPO10h
# Bridge detected between P7 and POz
# Bridge detected between P7 and O1
# Bridge detected between P7 and P5
# Bridge detected between P7 and PO3
# Bridge detected between P7 and PO7
# Bridge detected between P7 and TPP9h
# Bridge detected between P7 and PO9
# Bridge detected between P7 and P9
# Bridge detected between P7 and CPP5h
# Bridge detected between P7 and I1
# Bridge detected between P7 and TPP7h
# Bridge detected between P7 and PPO9h
# Bridge detected between P7 and PPO5h
# Bridge detected between P7 and POO9h
# Bridge detected between P7 and POO3h
# Bridge detected between P7 and OI1h
# Bridge detected between P3 and Pz
# Bridge detected between P3 and AF3
# Bridge detected between P3 and AF4
# Bridge detected between P3 and F5
# Bridge detected between P3 and F1
# Bridge detected between P3 and F2
# Bridge detected between P3 and F6
# Bridge detected between P3 and FC3
# Bridge detected between P3 and FCz
# Bridge detected between P3 and FC4
# Bridge detected between P3 and C1
# Bridge detected between P3 and C2
# Bridge detected between P3 and CP3
# Bridge detected between P3 and CP4
# Bridge detected between P3 and P1
# Bridge detected between P3 and P2
# Bridge detected between P3 and AFF1
# Bridge detected between P3 and AFz
# Bridge detected between P3 and AFF2
# Bridge detected between P3 and FFC5h
# Bridge detected between P3 and FFC3h
# Bridge detected between P3 and FFC4h
# Bridge detected between P3 and FFC6h
# Bridge detected between P3 and FCC5h
# Bridge detected between P3 and FCC3h
# Bridge detected between P3 and FCC4h
# Bridge detected between P3 and FCC6h
# Bridge detected between P3 and CCP3h
# Bridge detected between P3 and CCP4h
# Bridge detected between P3 and CPP3h
# Bridge detected between P3 and CPP4h
# Bridge detected between P3 and PPO2
# Bridge detected between P3 and AFp3h
# Bridge detected between P3 and AFF5h
# Bridge detected between P3 and AFF6h
# Bridge detected between P3 and FFT7h
# Bridge detected between P3 and FFC1h
# Bridge detected between P3 and FFC2h
# Bridge detected between P3 and FCC1h
# Bridge detected between P3 and FCC2h
# Bridge detected between P3 and CCP1h
# Bridge detected between P3 and CCP2h
# Bridge detected between P3 and CPP1h
# Bridge detected between P3 and CPP2h
# Bridge detected between Pz and AF3
# Bridge detected between Pz and AF4
# Bridge detected between Pz and F5
# Bridge detected between Pz and F1
# Bridge detected between Pz and F2
# Bridge detected between Pz and F6
# Bridge detected between Pz and FC3
# Bridge detected between Pz and FCz
# Bridge detected between Pz and FC4
# Bridge detected between Pz and C1
# Bridge detected between Pz and C2
# Bridge detected between Pz and CP3
# Bridge detected between Pz and CP4
# Bridge detected between Pz and P1
# Bridge detected between Pz and P2
# Bridge detected between Pz and AFF1
# Bridge detected between Pz and AFz
# Bridge detected between Pz and AFF2
# Bridge detected between Pz and FFC5h
# Bridge detected between Pz and FFC3h
# Bridge detected between Pz and FFC4h
# Bridge detected between Pz and FFC6h
# Bridge detected between Pz and FCC5h
# Bridge detected between Pz and FCC3h
# Bridge detected between Pz and FCC4h
# Bridge detected between Pz and FCC6h
# Bridge detected between Pz and CCP3h
# Bridge detected between Pz and CCP4h
# Bridge detected between Pz and CPP3h
# Bridge detected between Pz and CPP4h
# Bridge detected between Pz and PPO2
# Bridge detected between Pz and AFp3h
# Bridge detected between Pz and AFp4h
# Bridge detected between Pz and AFF5h
# Bridge detected between Pz and AFF6h
# Bridge detected between Pz and FFT7h
# Bridge detected between Pz and FFC1h
# Bridge detected between Pz and FFC2h
# Bridge detected between Pz and FCC1h
# Bridge detected between Pz and FCC2h
# Bridge detected between Pz and CCP1h
# Bridge detected between Pz and CCP2h
# Bridge detected between Pz and CPP1h
# Bridge detected between Pz and CPP2h
# Bridge detected between P4 and P8
# Bridge detected between P4 and P6
# Bridge detected between P4 and PO4
# Bridge detected between P4 and TP8
# Bridge detected between P4 and PO8
# Bridge detected between P4 and TPP10h
# Bridge detected between P4 and PO10
# Bridge detected between P4 and CCP6h
# Bridge detected between P4 and CPP6h
# Bridge detected between P4 and TTP8h
# Bridge detected between P4 and TPP8h
# Bridge detected between P4 and PPO6h
# Bridge detected between P4 and PPO10h
# Bridge detected between P8 and P6
# Bridge detected between P8 and PO4
# Bridge detected between P8 and TP8
# Bridge detected between P8 and PO8
# Bridge detected between P8 and TPP10h
# Bridge detected between P8 and PO10
# Bridge detected between P8 and CCP6h
# Bridge detected between P8 and CPP6h
# Bridge detected between P8 and TTP8h
# Bridge detected between P8 and TPP8h
# Bridge detected between P8 and PPO6h
# Bridge detected between P8 and PPO10h
# Bridge detected between POz and O1
# Bridge detected between POz and P5
# Bridge detected between POz and PO3
# Bridge detected between POz and PO7
# Bridge detected between POz and TPP9h
# Bridge detected between POz and PO9
# Bridge detected between POz and P9
# Bridge detected between POz and CPP5h
# Bridge detected between POz and PPO1
# Bridge detected between POz and I1
# Bridge detected between POz and TPP7h
# Bridge detected between POz and PPO9h
# Bridge detected between POz and PPO5h
# Bridge detected between POz and POO9h
# Bridge detected between POz and POO3h
# Bridge detected between POz and POO4h
# Bridge detected between POz and OI1h
# Bridge detected between O1 and P5
# Bridge detected between O1 and PO3
# Bridge detected between O1 and PO7
# Bridge detected between O1 and TPP9h
# Bridge detected between O1 and PO9
# Bridge detected between O1 and P9
# Bridge detected between O1 and CPP5h
# Bridge detected between O1 and I1
# Bridge detected between O1 and TPP7h
# Bridge detected between O1 and PPO9h
# Bridge detected between O1 and PPO5h
# Bridge detected between O1 and POO9h
# Bridge detected between O1 and POO3h
# Bridge detected between O1 and OI1h
# Bridge detected between O2 and Iz
# Bridge detected between O2 and I2
# Bridge detected between O2 and POO10h
# Bridge detected between O2 and OI2h
# Bridge detected between AF7 and AF3
# Bridge detected between AF7 and F5
# Bridge detected between AF7 and FFC5h
# Bridge detected between AF7 and FCC5h
# Bridge detected between AF7 and AFp3h
# Bridge detected between AF7 and AFF5h
# Bridge detected between AF7 and FFT7h
# Bridge detected between AF7 and FFT8h
# Bridge detected between AF3 and AF4
# Bridge detected between AF3 and AF8
# Bridge detected between AF3 and F5
# Bridge detected between AF3 and F1
# Bridge detected between AF3 and F2
# Bridge detected between AF3 and F6
# Bridge detected between AF3 and FC3
# Bridge detected between AF3 and FCz
# Bridge detected between AF3 and FC4
# Bridge detected between AF3 and C5
# Bridge detected between AF3 and C1
# Bridge detected between AF3 and C2
# Bridge detected between AF3 and CP4
# Bridge detected between AF3 and P1
# Bridge detected between AF3 and P2
# Bridge detected between AF3 and FT7
# Bridge detected between AF3 and AFF1
# Bridge detected between AF3 and AFz
# Bridge detected between AF3 and AFF2
# Bridge detected between AF3 and FFC5h
# Bridge detected between AF3 and FFC3h
# Bridge detected between AF3 and FFC4h
# Bridge detected between AF3 and FFC6h
# Bridge detected between AF3 and FCC5h
# Bridge detected between AF3 and FCC3h
# Bridge detected between AF3 and FCC4h
# Bridge detected between AF3 and FCC6h
# Bridge detected between AF3 and CCP5h
# Bridge detected between AF3 and CCP3h
# Bridge detected between AF3 and CCP4h
# Bridge detected between AF3 and CPP3h
# Bridge detected between AF3 and CPP4h
# Bridge detected between AF3 and PPO2
# Bridge detected between AF3 and AFp3h
# Bridge detected between AF3 and AFp4h
# Bridge detected between AF3 and AFF5h
# Bridge detected between AF3 and AFF6h
# Bridge detected between AF3 and FFT7h
# Bridge detected between AF3 and FFC1h
# Bridge detected between AF3 and FFC2h
# Bridge detected between AF3 and FFT8h
# Bridge detected between AF3 and FTT7h
# Bridge detected between AF3 and FCC1h
# Bridge detected between AF3 and FCC2h
# Bridge detected between AF3 and TTP7h
# Bridge detected between AF3 and CCP1h
# Bridge detected between AF3 and CCP2h
# Bridge detected between AF3 and CPP1h
# Bridge detected between AF3 and CPP2h
# Bridge detected between AF4 and F5
# Bridge detected between AF4 and F1
# Bridge detected between AF4 and F2
# Bridge detected between AF4 and F6
# Bridge detected between AF4 and FC3
# Bridge detected between AF4 and FCz
# Bridge detected between AF4 and FC4
# Bridge detected between AF4 and C1
# Bridge detected between AF4 and C2
# Bridge detected between AF4 and CP3
# Bridge detected between AF4 and CP4
# Bridge detected between AF4 and P1
# Bridge detected between AF4 and P2
# Bridge detected between AF4 and AFF1
# Bridge detected between AF4 and AFz
# Bridge detected between AF4 and AFF2
# Bridge detected between AF4 and FFC5h
# Bridge detected between AF4 and FFC3h
# Bridge detected between AF4 and FFC4h
# Bridge detected between AF4 and FFC6h
# Bridge detected between AF4 and FCC5h
# Bridge detected between AF4 and FCC3h
# Bridge detected between AF4 and FCC4h
# Bridge detected between AF4 and FCC6h
# Bridge detected between AF4 and CCP3h
# Bridge detected between AF4 and CCP4h
# Bridge detected between AF4 and CPP3h
# Bridge detected between AF4 and CPP4h
# Bridge detected between AF4 and PPO2
# Bridge detected between AF4 and AFp3h
# Bridge detected between AF4 and AFp4h
# Bridge detected between AF4 and AFF5h
# Bridge detected between AF4 and AFF6h
# Bridge detected between AF4 and FFT7h
# Bridge detected between AF4 and FFC1h
# Bridge detected between AF4 and FFC2h
# Bridge detected between AF4 and FCC1h
# Bridge detected between AF4 and FCC2h
# Bridge detected between AF4 and CCP1h
# Bridge detected between AF4 and CCP2h
# Bridge detected between AF4 and CPP1h
# Bridge detected between AF4 and CPP2h
# Bridge detected between AF8 and F5
# Bridge detected between AF8 and FFC5h
# Bridge detected between AF8 and FCC5h
# Bridge detected between AF8 and AFp3h
# Bridge detected between AF8 and AFp4h
# Bridge detected between AF8 and AFF5h
# Bridge detected between AF8 and FFT7h
# Bridge detected between F5 and F1
# Bridge detected between F5 and F2
# Bridge detected between F5 and F6
# Bridge detected between F5 and FC3
# Bridge detected between F5 and FCz
# Bridge detected between F5 and FC4
# Bridge detected between F5 and C5
# Bridge detected between F5 and C1
# Bridge detected between F5 and C2
# Bridge detected between F5 and CP4
# Bridge detected between F5 and P1
# Bridge detected between F5 and P2
# Bridge detected between F5 and FT7
# Bridge detected between F5 and AFF1
# Bridge detected between F5 and AFz
# Bridge detected between F5 and AFF2
# Bridge detected between F5 and FFC5h
# Bridge detected between F5 and FFC3h
# Bridge detected between F5 and FFC4h
# Bridge detected between F5 and FFC6h
# Bridge detected between F5 and FCC5h
# Bridge detected between F5 and FCC3h
# Bridge detected between F5 and FCC4h
# Bridge detected between F5 and FCC6h
# Bridge detected between F5 and CCP5h
# Bridge detected between F5 and CCP3h
# Bridge detected between F5 and CCP4h
# Bridge detected between F5 and CPP3h
# Bridge detected between F5 and CPP4h
# Bridge detected between F5 and PPO2
# Bridge detected between F5 and AFp3h
# Bridge detected between F5 and AFp4h
# Bridge detected between F5 and AFF5h
# Bridge detected between F5 and AFF6h
# Bridge detected between F5 and FFT7h
# Bridge detected between F5 and FFC1h
# Bridge detected between F5 and FFC2h
# Bridge detected between F5 and FFT8h
# Bridge detected between F5 and FTT7h
# Bridge detected between F5 and FCC1h
# Bridge detected between F5 and FCC2h
# Bridge detected between F5 and TTP7h
# Bridge detected between F5 and CCP1h
# Bridge detected between F5 and CCP2h
# Bridge detected between F5 and CPP1h
# Bridge detected between F5 and CPP2h
# Bridge detected between F1 and F2
# Bridge detected between F1 and F6
# Bridge detected between F1 and FC3
# Bridge detected between F1 and FCz
# Bridge detected between F1 and FC4
# Bridge detected between F1 and C1
# Bridge detected between F1 and C2
# Bridge detected between F1 and CP4
# Bridge detected between F1 and P1
# Bridge detected between F1 and P2
# Bridge detected between F1 and AFF1
# Bridge detected between F1 and AFz
# Bridge detected between F1 and AFF2
# Bridge detected between F1 and FFC5h
# Bridge detected between F1 and FFC3h
# Bridge detected between F1 and FFC4h
# Bridge detected between F1 and FFC6h
# Bridge detected between F1 and FCC5h
# Bridge detected between F1 and FCC3h
# Bridge detected between F1 and FCC4h
# Bridge detected between F1 and FCC6h
# Bridge detected between F1 and CCP3h
# Bridge detected between F1 and CCP4h
# Bridge detected between F1 and CPP3h
# Bridge detected between F1 and CPP4h
# Bridge detected between F1 and PPO2
# Bridge detected between F1 and AFp3h
# Bridge detected between F1 and AFp4h
# Bridge detected between F1 and AFF5h
# Bridge detected between F1 and AFF6h
# Bridge detected between F1 and FFT7h
# Bridge detected between F1 and FFC1h
# Bridge detected between F1 and FFC2h
# Bridge detected between F1 and FCC1h
# Bridge detected between F1 and FCC2h
# Bridge detected between F1 and CCP1h
# Bridge detected between F1 and CCP2h
# Bridge detected between F1 and CPP1h
# Bridge detected between F1 and CPP2h
# Bridge detected between F2 and F6
# Bridge detected between F2 and FC3
# Bridge detected between F2 and FCz
# Bridge detected between F2 and FC4
# Bridge detected between F2 and C1
# Bridge detected between F2 and C2
# Bridge detected between F2 and CP3
# Bridge detected between F2 and CP4
# Bridge detected between F2 and P1
# Bridge detected between F2 and P2
# Bridge detected between F2 and AFF1
# Bridge detected between F2 and AFz
# Bridge detected between F2 and AFF2
# Bridge detected between F2 and FFC5h
# Bridge detected between F2 and FFC3h
# Bridge detected between F2 and FFC4h
# Bridge detected between F2 and FFC6h
# Bridge detected between F2 and FCC5h
# Bridge detected between F2 and FCC3h
# Bridge detected between F2 and FCC4h
# Bridge detected between F2 and FCC6h
# Bridge detected between F2 and CCP3h
# Bridge detected between F2 and CCP4h
# Bridge detected between F2 and CPP3h
# Bridge detected between F2 and CPP4h
# Bridge detected between F2 and PPO2
# Bridge detected between F2 and AFp3h
# Bridge detected between F2 and AFp4h
# Bridge detected between F2 and AFF5h
# Bridge detected between F2 and AFF6h
# Bridge detected between F2 and FFT7h
# Bridge detected between F2 and FFC1h
# Bridge detected between F2 and FFC2h
# Bridge detected between F2 and FCC1h
# Bridge detected between F2 and FCC2h
# Bridge detected between F2 and CCP1h
# Bridge detected between F2 and CCP2h
# Bridge detected between F2 and CPP1h
# Bridge detected between F2 and CPP2h
# Bridge detected between F6 and FC3
# Bridge detected between F6 and FCz
# Bridge detected between F6 and FC4
# Bridge detected between F6 and C1
# Bridge detected between F6 and C2
# Bridge detected between F6 and CP3
# Bridge detected between F6 and CP4
# Bridge detected between F6 and P1
# Bridge detected between F6 and P2
# Bridge detected between F6 and AFF1
# Bridge detected between F6 and AFz
# Bridge detected between F6 and AFF2
# Bridge detected between F6 and FFC5h
# Bridge detected between F6 and FFC3h
# Bridge detected between F6 and FFC4h
# Bridge detected between F6 and FFC6h
# Bridge detected between F6 and FCC5h
# Bridge detected between F6 and FCC3h
# Bridge detected between F6 and FCC4h
# Bridge detected between F6 and FCC6h
# Bridge detected between F6 and CCP3h
# Bridge detected between F6 and CCP4h
# Bridge detected between F6 and CPP3h
# Bridge detected between F6 and CPP4h
# Bridge detected between F6 and PPO2
# Bridge detected between F6 and AFp3h
# Bridge detected between F6 and AFp4h
# Bridge detected between F6 and AFF5h
# Bridge detected between F6 and AFF6h
# Bridge detected between F6 and FFT7h
# Bridge detected between F6 and FFC1h
# Bridge detected between F6 and FFC2h
# Bridge detected between F6 and FCC1h
# Bridge detected between F6 and FCC2h
# Bridge detected between F6 and CCP1h
# Bridge detected between F6 and CCP2h
# Bridge detected between F6 and CPP1h
# Bridge detected between F6 and CPP2h
# Bridge detected between FC3 and FCz
# Bridge detected between FC3 and FC4
# Bridge detected between FC3 and C1
# Bridge detected between FC3 and C2
# Bridge detected between FC3 and CP3
# Bridge detected between FC3 and CP4
# Bridge detected between FC3 and P1
# Bridge detected between FC3 and P2
# Bridge detected between FC3 and AFF1
# Bridge detected between FC3 and AFz
# Bridge detected between FC3 and AFF2
# Bridge detected between FC3 and FFC5h
# Bridge detected between FC3 and FFC3h
# Bridge detected between FC3 and FFC4h
# Bridge detected between FC3 and FFC6h
# Bridge detected between FC3 and FCC5h
# Bridge detected between FC3 and FCC3h
# Bridge detected between FC3 and FCC4h
# Bridge detected between FC3 and FCC6h
# Bridge detected between FC3 and CCP3h
# Bridge detected between FC3 and CCP4h
# Bridge detected between FC3 and CPP3h
# Bridge detected between FC3 and CPP4h
# Bridge detected between FC3 and PPO2
# Bridge detected between FC3 and AFp3h
# Bridge detected between FC3 and AFp4h
# Bridge detected between FC3 and AFF5h
# Bridge detected between FC3 and AFF6h
# Bridge detected between FC3 and FFT7h
# Bridge detected between FC3 and FFC1h
# Bridge detected between FC3 and FFC2h
# Bridge detected between FC3 and FCC1h
# Bridge detected between FC3 and FCC2h
# Bridge detected between FC3 and CCP1h
# Bridge detected between FC3 and CCP2h
# Bridge detected between FC3 and CPP1h
# Bridge detected between FC3 and CPP2h
# Bridge detected between FCz and FC4
# Bridge detected between FCz and C1
# Bridge detected between FCz and C2
# Bridge detected between FCz and CP4
# Bridge detected between FCz and P1
# Bridge detected between FCz and P2
# Bridge detected between FCz and AFF1
# ...
# Bridge detected between FFC5h and FCC4h
# Bridge detected between FFC5h and FCC6h
# Bridge detected between FFC5h and CCP5h
# Bridge detected between FFC5h and CCP3h
# Bridge detected between FFC5h and CCP4h
# Bridge detected between FFC5h and CPP3h
# Bridge detected between FFC5h and CPP4h
# Bridge detected between FFC5h and PPO2
# Bridge detected between FFC5h and AFp3h
# Bridge detected between FFC5h and AFp4h
# Bridge detected between FFC5h and AFF5h
# Bridge detected between FFC5h and AFF6h
# Bridge detected between FFC5h and FFT7h
# Bridge detected between FFC5h and FFC1h
# Bridge detected between FFC5h and FFC2h
# Bridge detected between FFC5h and FFT8h
# Bridge detected between FFC5h and FTT7h
# Bridge detected between FFC5h and FCC1h
# Bridge detected between FFC5h and FCC2h
# Bridge detected between FFC5h and TTP7h
# Bridge detected between FFC5h and CCP1h
# Bridge detected between FFC5h and CCP2h
# Bridge detected between FFC5h and CPP1h
# Bridge detected between FFC5h and CPP2h
# Bridge detected between FFC3h and FFC4h
# Bridge detected between FFC3h and FFC6h
# Bridge detected between FFC3h and FCC5h
# Bridge detected between FFC3h and FCC3h
# Bridge detected between FFC3h and FCC4h
# Bridge detected between FFC3h and FCC6h
# Bridge detected between FFC3h and CCP3h
# Bridge detected between FFC3h and CCP4h
# Bridge detected between FFC3h and CPP3h
# Bridge detected between FFC3h and CPP4h
# Bridge detected between FFC3h and PPO2
# Bridge detected between FFC3h and AFp3h
# Bridge detected between FFC3h and AFp4h
# Bridge detected between FFC3h and AFF5h
# Bridge detected between FFC3h and AFF6h
# Bridge detected between FFC3h and FFT7h
# Bridge detected between FFC3h and FFC1h
# Bridge detected between FFC3h and FFC2h
# Bridge detected between FFC3h and FCC1h
# Bridge detected between FFC3h and FCC2h
# Bridge detected between FFC3h and CCP1h
# Bridge detected between FFC3h and CCP2h
# Bridge detected between FFC3h and CPP1h
# Bridge detected between FFC3h and CPP2h
# Bridge detected between FFC4h and FFC6h
# Bridge detected between FFC4h and FCC5h
# Bridge detected between FFC4h and FCC3h
# Bridge detected between FFC4h and FCC4h
# Bridge detected between FFC4h and FCC6h
# Bridge detected between FFC4h and CCP3h
# Bridge detected between FFC4h and CCP4h
# Bridge detected between FFC4h and CPP3h
# Bridge detected between FFC4h and CPP4h
# Bridge detected between FFC4h and PPO2
# Bridge detected between FFC4h and AFp3h
# Bridge detected between FFC4h and AFp4h
# Bridge detected between FFC4h and AFF5h
# Bridge detected between FFC4h and AFF6h
# Bridge detected between FFC4h and FFT7h
# Bridge detected between FFC4h and FFC1h
# Bridge detected between FFC4h and FFC2h
# Bridge detected between FFC4h and FCC1h
# Bridge detected between FFC4h and FCC2h
# Bridge detected between FFC4h and CCP1h
# Bridge detected between FFC4h and CCP2h
# Bridge detected between FFC4h and CPP1h
# Bridge detected between FFC4h and CPP2h
# Bridge detected between FFC6h and FCC5h
# Bridge detected between FFC6h and FCC3h
# Bridge detected between FFC6h and FCC4h
# Bridge detected between FFC6h and FCC6h
# Bridge detected between FFC6h and CCP3h
# Bridge detected between FFC6h and CCP4h
# Bridge detected between FFC6h and CPP3h
# Bridge detected between FFC6h and CPP4h
# Bridge detected between FFC6h and PPO2
# Bridge detected between FFC6h and AFp3h
# Bridge detected between FFC6h and AFp4h
# Bridge detected between FFC6h and AFF5h
# Bridge detected between FFC6h and AFF6h
# Bridge detected between FFC6h and FFT7h
# Bridge detected between FFC6h and FFC1h
# Bridge detected between FFC6h and FFC2h
# Bridge detected between FFC6h and FCC1h
# Bridge detected between FFC6h and FCC2h
# Bridge detected between FFC6h and CCP1h
# Bridge detected between FFC6h and CCP2h
# Bridge detected between FFC6h and CPP1h
# Bridge detected between FFC6h and CPP2h
# Bridge detected between FCC5h and FCC3h
# Bridge detected between FCC5h and FCC4h
# Bridge detected between FCC5h and FCC6h
# Bridge detected between FCC5h and CCP5h
# Bridge detected between FCC5h and CCP3h
# Bridge detected between FCC5h and CCP4h
# Bridge detected between FCC5h and CPP3h
# Bridge detected between FCC5h and CPP4h
# Bridge detected between FCC5h and PPO2
# Bridge detected between FCC5h and AFp3h
# Bridge detected between FCC5h and AFp4h
# Bridge detected between FCC5h and AFF5h
# Bridge detected between FCC5h and AFF6h
# Bridge detected between FCC5h and FFT7h
# Bridge detected between FCC5h and FFC1h
# Bridge detected between FCC5h and FFC2h
# Bridge detected between FCC5h and FFT8h
# Bridge detected between FCC5h and FTT7h
# Bridge detected between FCC5h and FCC1h
# Bridge detected between FCC5h and FCC2h
# Bridge detected between FCC5h and TTP7h
# Bridge detected between FCC5h and CCP1h
# Bridge detected between FCC5h and CCP2h
# Bridge detected between FCC5h and CPP1h
# Bridge detected between FCC5h and CPP2h
# Bridge detected between FCC3h and FCC4h
# Bridge detected between FCC3h and FCC6h
# Bridge detected between FCC3h and CCP3h
# Bridge detected between FCC3h and CCP4h
# Bridge detected between FCC3h and CPP3h
# Bridge detected between FCC3h and CPP4h
# Bridge detected between FCC3h and PPO2
# Bridge detected between FCC3h and AFp3h
# Bridge detected between FCC3h and AFp4h
# Bridge detected between FCC3h and AFF5h
# Bridge detected between FCC3h and AFF6h
# Bridge detected between FCC3h and FFT7h
# Bridge detected between FCC3h and FFC1h
# Bridge detected between FCC3h and FFC2h
# Bridge detected between FCC3h and FCC1h
# Bridge detected between FCC3h and FCC2h
# Bridge detected between FCC3h and CCP1h
# Bridge detected between FCC3h and CCP2h
# Bridge detected between FCC3h and CPP1h
# Bridge detected between FCC3h and CPP2h
# Bridge detected between FCC4h and FCC6h
# Bridge detected between FCC4h and CCP3h
# Bridge detected between FCC4h and CCP4h
# Bridge detected between FCC4h and CPP3h
# Bridge detected between FCC4h and CPP4h
# Bridge detected between FCC4h and PPO2
# Bridge detected between FCC4h and AFp3h
# Bridge detected between FCC4h and AFp4h
# Bridge detected between FCC4h and AFF5h
# Bridge detected between FCC4h and AFF6h
# Bridge detected between FCC4h and FFT7h
# Bridge detected between FCC4h and FFC1h
# Bridge detected between FCC4h and FFC2h
# Bridge detected between FCC4h and FCC1h
# Bridge detected between FCC4h and FCC2h
# Bridge detected between FCC4h and CCP1h
# Bridge detected between FCC4h and CCP2h
# Bridge detected between FCC4h and CPP1h
# Bridge detected between FCC4h and CPP2h
# Bridge detected between FCC6h and CCP3h
# Bridge detected between FCC6h and CCP4h
# Bridge detected between FCC6h and CPP3h
# Bridge detected between FCC6h and CPP4h
# Bridge detected between FCC6h and PPO2
# Bridge detected between FCC6h and AFp3h
# Bridge detected between FCC6h and AFp4h
# Bridge detected between FCC6h and AFF5h
# Bridge detected between FCC6h and AFF6h
# Bridge detected between FCC6h and FFT7h
# Bridge detected between FCC6h and FFC1h
# Bridge detected between FCC6h and FFC2h
# Bridge detected between FCC6h and FCC1h
# Bridge detected between FCC6h and FCC2h
# Bridge detected between FCC6h and CCP1h
# Bridge detected between FCC6h and CCP2h
# Bridge detected between FCC6h and CPP1h
# Bridge detected between FCC6h and CPP2h
# Bridge detected between CCP5h and AFp3h
# Bridge detected between CCP5h and AFp4h
# Bridge detected between CCP5h and AFF5h
# Bridge detected between CCP5h and FFT7h
# Bridge detected between CCP5h and FTT9h
# Bridge detected between CCP5h and FTT7h
# Bridge detected between CCP5h and TTP7h
# Bridge detected between CCP3h and CCP4h
# Bridge detected between CCP3h and CPP3h
# Bridge detected between CCP3h and CPP4h
# Bridge detected between CCP3h and PPO2
# Bridge detected between CCP3h and AFp3h
# Bridge detected between CCP3h and AFp4h
# Bridge detected between CCP3h and AFF5h
# Bridge detected between CCP3h and AFF6h
# Bridge detected between CCP3h and FFT7h
# Bridge detected between CCP3h and FFC1h
# Bridge detected between CCP3h and FFC2h
# Bridge detected between CCP3h and FCC1h
# Bridge detected between CCP3h and FCC2h
# Bridge detected between CCP3h and CCP1h
# Bridge detected between CCP3h and CCP2h
# Bridge detected between CCP3h and CPP1h
# Bridge detected between CCP3h and CPP2h
# Bridge detected between CCP4h and CPP3h
# Bridge detected between CCP4h and CPP4h
# Bridge detected between CCP4h and PPO2
# Bridge detected between CCP4h and AFp3h
# Bridge detected between CCP4h and AFp4h
# Bridge detected between CCP4h and AFF5h
# Bridge detected between CCP4h and AFF6h
# Bridge detected between CCP4h and FFT7h
# Bridge detected between CCP4h and FFC1h
# Bridge detected between CCP4h and FFC2h
# Bridge detected between CCP4h and FCC1h
# Bridge detected between CCP4h and FCC2h
# Bridge detected between CCP4h and CCP1h
# Bridge detected between CCP4h and CCP2h
# Bridge detected between CCP4h and CPP1h
# Bridge detected between CCP4h and CPP2h
# Bridge detected between CCP6h and CPP6h
# Bridge detected between CCP6h and TTP8h
# Bridge detected between CCP6h and TPP8h
# Bridge detected between CCP6h and PPO6h
# Bridge detected between CCP6h and PPO10h
# Bridge detected between CPP5h and I1
# Bridge detected between CPP5h and TPP7h
# Bridge detected between CPP5h and PPO9h
# Bridge detected between CPP5h and PPO5h
# Bridge detected between CPP5h and POO9h
# Bridge detected between CPP5h and POO3h
# Bridge detected between CPP5h and OI1h
# Bridge detected between CPP3h and CPP4h
# Bridge detected between CPP3h and PPO2
# Bridge detected between CPP3h and AFp3h
# Bridge detected between CPP3h and AFF5h
# Bridge detected between CPP3h and AFF6h
# Bridge detected between CPP3h and FFT7h
# Bridge detected between CPP3h and FFC1h
# Bridge detected between CPP3h and FFC2h
# Bridge detected between CPP3h and FCC1h
# Bridge detected between CPP3h and FCC2h
# Bridge detected between CPP3h and CCP1h
# Bridge detected between CPP3h and CCP2h
# Bridge detected between CPP3h and CPP1h
# Bridge detected between CPP3h and CPP2h
# Bridge detected between CPP4h and PPO2
# Bridge detected between CPP4h and AFp3h
# Bridge detected between CPP4h and AFp4h
# Bridge detected between CPP4h and AFF5h
# Bridge detected between CPP4h and AFF6h
# Bridge detected between CPP4h and FFT7h
# Bridge detected between CPP4h and FFC1h
# Bridge detected between CPP4h and FFC2h
# Bridge detected between CPP4h and FCC1h
# Bridge detected between CPP4h and FCC2h
# Bridge detected between CPP4h and CCP1h
# Bridge detected between CPP4h and CCP2h
# Bridge detected between CPP4h and CPP1h
# Bridge detected between CPP4h and CPP2h
# Bridge detected between CPP6h and TTP8h
# Bridge detected between CPP6h and TPP8h
# Bridge detected between CPP6h and PPO6h
# Bridge detected between CPP6h and PPO10h
# Bridge detected between PPO1 and PPO5h
# Bridge detected between PPO1 and POO3h
# Bridge detected between PPO1 and POO4h
# Bridge detected between PPO2 and AFp3h
# Bridge detected between PPO2 and AFp4h
# Bridge detected between PPO2 and AFF5h
# Bridge detected between PPO2 and AFF6h
# Bridge detected between PPO2 and FFT7h
# Bridge detected between PPO2 and FFC1h
# Bridge detected between PPO2 and FFC2h
# Bridge detected between PPO2 and FCC1h
# Bridge detected between PPO2 and FCC2h
# Bridge detected between PPO2 and CCP1h
# Bridge detected between PPO2 and CCP2h
# Bridge detected between PPO2 and CPP1h
# Bridge detected between PPO2 and CPP2h
# Bridge detected between I1 and TPP7h
# Bridge detected between I1 and PPO9h
# Bridge detected between I1 and PPO5h
# Bridge detected between I1 and POO9h
# Bridge detected between I1 and POO3h
# Bridge detected between I1 and OI1h
# Bridge detected between Iz and I2
# Bridge detected between Iz and POO10h
# Bridge detected between Iz and OI2h
# Bridge detected between I2 and POO10h
# Bridge detected between I2 and OI2h
# Bridge detected between AFp3h and AFp4h
# Bridge detected between AFp3h and AFF5h
# Bridge detected between AFp3h and AFF6h
# Bridge detected between AFp3h and FFT7h
# Bridge detected between AFp3h and FFC1h
# Bridge detected between AFp3h and FFC2h
# Bridge detected between AFp3h and FFT8h
# Bridge detected between AFp3h and FTT7h
# Bridge detected between AFp3h and FCC1h
# Bridge detected between AFp3h and FCC2h
# Bridge detected between AFp3h and TTP7h
# Bridge detected between AFp3h and CCP1h
# Bridge detected between AFp3h and CCP2h
# Bridge detected between AFp3h and CPP1h
# Bridge detected between AFp3h and CPP2h
# Bridge detected between AFp4h and AFF5h
# Bridge detected between AFp4h and AFF6h
# Bridge detected between AFp4h and FFT7h
# Bridge detected between AFp4h and FFC1h
# Bridge detected between AFp4h and FFC2h
# Bridge detected between AFp4h and FFT8h
# Bridge detected between AFp4h and FTT7h
# Bridge detected between AFp4h and FCC1h
# Bridge detected between AFp4h and FCC2h
# Bridge detected between AFp4h and TTP7h
# Bridge detected between AFp4h and CCP2h
# Bridge detected between AFp4h and CPP1h
# Bridge detected between AFp4h and CPP2h
# Bridge detected between AFF5h and AFF6h
# Bridge detected between AFF5h and FFT7h
# Bridge detected between AFF5h and FFC1h
# Bridge detected between AFF5h and FFC2h
# Bridge detected between AFF5h and FFT8h
# Bridge detected between AFF5h and FTT7h
# Bridge detected between AFF5h and FCC1h
# Bridge detected between AFF5h and FCC2h
# Bridge detected between AFF5h and TTP7h
# Bridge detected between AFF5h and CCP1h
# Bridge detected between AFF5h and CCP2h
# Bridge detected between AFF5h and CPP1h
# Bridge detected between AFF5h and CPP2h
# Bridge detected between AFF6h and FFT7h
# Bridge detected between AFF6h and FFC1h
# Bridge detected between AFF6h and FFC2h
# Bridge detected between AFF6h and FCC1h
# Bridge detected between AFF6h and FCC2h
# Bridge detected between AFF6h and CCP1h
# Bridge detected between AFF6h and CCP2h
# Bridge detected between AFF6h and CPP1h
# Bridge detected between AFF6h and CPP2h
# Bridge detected between FFT7h and FFC1h
# Bridge detected between FFT7h and FFC2h
# Bridge detected between FFT7h and FFT8h
# Bridge detected between FFT7h and FTT7h
# Bridge detected between FFT7h and FCC1h
# Bridge detected between FFT7h and FCC2h
# Bridge detected between FFT7h and TTP7h
# Bridge detected between FFT7h and CCP1h
# Bridge detected between FFT7h and CCP2h
# Bridge detected between FFT7h and CPP1h
# Bridge detected between FFT7h and CPP2h
# Bridge detected between FFC1h and FFC2h
# Bridge detected between FFC1h and FCC1h
# Bridge detected between FFC1h and FCC2h
# Bridge detected between FFC1h and CCP1h
# Bridge detected between FFC1h and CCP2h
# Bridge detected between FFC1h and CPP1h
# Bridge detected between FFC1h and CPP2h
# Bridge detected between FFC2h and FCC1h
# Bridge detected between FFC2h and FCC2h
# Bridge detected between FFC2h and CCP1h
# Bridge detected between FFC2h and CCP2h
# Bridge detected between FFC2h and CPP1h
# Bridge detected between FFC2h and CPP2h
# Bridge detected between FTT9h and FTT7h
# Bridge detected between FTT9h and TTP7h
# Bridge detected between FTT7h and TTP7h
# Bridge detected between FCC1h and FCC2h
# Bridge detected between FCC1h and CCP1h
# Bridge detected between FCC1h and CCP2h
# Bridge detected between FCC1h and CPP1h
# Bridge detected between FCC1h and CPP2h
# Bridge detected between FCC2h and CCP1h
# Bridge detected between FCC2h and CCP2h
# Bridge detected between FCC2h and CPP1h
# Bridge detected between FCC2h and CPP2h
# Bridge detected between FTT8h and FTT10h
# Bridge detected between CCP1h and CCP2h
# Bridge detected between CCP1h and CPP1h
# Bridge detected between CCP1h and CPP2h
# Bridge detected between CCP2h and CPP1h
# Bridge detected between CCP2h and CPP2h
# Bridge detected between TTP8h and TPP8h
# Bridge detected between TTP8h and PPO6h
# Bridge detected between TTP8h and PPO10h
# Bridge detected between TPP7h and PPO9h
# Bridge detected between TPP7h and PPO5h
# Bridge detected between TPP7h and POO9h
# Bridge detected between TPP7h and POO3h
# Bridge detected between TPP7h and OI1h
# Bridge detected between CPP1h and CPP2h
# Bridge detected between TPP8h and PPO6h
# Bridge detected between TPP8h and PPO10h
# Bridge detected between PPO9h and PPO5h
# Bridge detected between PPO9h and POO9h
# Bridge detected between PPO9h and POO3h
# Bridge detected between PPO9h and OI1h
# Bridge detected between PPO5h and POO9h
# Bridge detected between PPO5h and POO3h
# Bridge detected between PPO5h and OI1h
# Bridge detected between PPO6h and PPO10h
# Bridge detected between POO9h and POO3h
# Bridge detected between POO9h and OI1h
# Bridge detected between POO3h and OI1h
# Bridge detected between POO10h and OI2h

# %%
import numpy as np

data = subject.get_data()
corr = np.corrcoef(data)

import matplotlib.pyplot as plt
plt.imshow(corr, vmin=-1, vmax=1, cmap='coolwarm')
plt.colorbar()

for i in range(10):
    print(np.corrcoef(data[0], data[i])[0,1])

mne.viz.plot_bridged_electrodes(
    subject.info,
    bridged_idx,
    ed_matrix,
    title="Subject 6 Bridged Electrodes",
    topomap_args=dict(vlim=(None, 5)),
)
# Out:
# 1.0
# 0.6313363517740234
# 0.8096695383474425
# 0.7431219252383509
# 0.3616425527823108
# 0.2709629007253814
# 0.19717393207084355
# 0.6551394846789719
# 0.7463304669615677
# 0.36192141656941684

# %% [markdown]
# This shit is apparently the correct result of "I love every part of me" AND the inner child connection is strong. Even tho the get_data suggest its maybe the doing of time (TODOO: where and when it happens)

# %% [markdown]
# <h2>Jak to zrychlit ?</h2>
# Using pre function to analyse how similar are last 10 second of downsampled data of subject
#
# Print it and then compere or decide if subject should continue

# %%
def plot_debug(raw_crop, data, corr, bridged_idx, ed_matrix):

    # korelační matice
    plt.figure(figsize=(6, 5))
    plt.imshow(corr, vmin=-1, vmax=1, cmap='coolwarm')
    plt.title("Correlation matrix")
    plt.colorbar()
    plt.show()

    # pár korelací pro sanity check
    print("\nSample correlations vs channel 0:")
    for i in range(min(10, data.shape[0])):
        print(f"{i}: {np.corrcoef(data[0], data[i])[0,1]:.3f}")

    # bridges vizualizace
    mne.viz.plot_bridged_electrodes(
        raw_crop.info,
        bridged_idx,
        ed_matrix,
        title="Bridged Electrodes (FAST)",
        topomap_args=dict(vlim=(None, 5)),
    )

# %%
import numpy as np
import matplotlib.pyplot as plt
import mne

path = './../data/C01/C01_2024-11-16_10-44-51_RS_before_ica.fif'
subject = mne.io.read_raw_fif(path, preload=True)
montage = mne.channels.make_standard_montage("standard_1005")
subject.set_montage(montage)

def compute_bridges_fast_debug(raw, seconds=10, new_freq=100, threshold=0.95):
    raw_len = raw.n_times
    raw_freq = raw.sfreq

    # 1. crop posledních X sekund
    print("tu")
    tmax = raw.times[-1]
    tmin = tmax - seconds
    raw_crop = raw.copy().crop(tmin=tmin, tmax=tmax)
    
    # 2. jen EEG kanály
    print("tuna")
    raw_crop.pick_types(eeg=True)
    
    # 3. downsample
    print("tutuna")
    raw_crop.resample(sfreq)
    
    # vysledky jako korelace
    print("tuna tuna ")
    corr = np.corrcoef(raw_crop.get_data())

    # actual bridges
    print("tuuuuuuuuuuuuuuuuuuuuuuuuuuuu")
    bridged_idx, ed_matrix = mne.preprocessing.compute_bridged_electrodes(
        raw_crop,
        threshold=threshold
    )

    return raw_crop, data, corr, bridged_idx, ed_matrix

sub_crop, sub_data, sub_corr, sub_bridgedIdx, sub_edMatrix = compute_bridges_fast_debug(subject)
plot_debug(sub_crop, sub_data, sub_corr, sub_bridgedIdxb, sub_edMatrix)
