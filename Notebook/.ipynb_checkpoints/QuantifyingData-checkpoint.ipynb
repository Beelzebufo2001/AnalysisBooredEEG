# %% [markdown]
# <h1>Data Output Comparison and Quantifying</h1>
#
# **Next station is data comparison and quantiying difference between data.**
#
# - Lets say that nothing around bridges makes sense and even tho 06 suposed to be nice, both plv and corr matrices looking blank as board or my chest.
# - We now want to take 10 s or something at the begining of Eyes open and compare it at the first 10 s Eyes closed.
# - *We want to do that with* Comparing first few seconds of EO to the last few seconds of EO, same as FEO to FEC, LEO to the FEC, and FEC to the LEC.
# - We want to do it with plv and corr matrices too. So result would be picture, pdf or something containing data of *"this is how the timeline looks in standard ylim, this is how it looks without ylim and alll the other data with EO, EC comparison with both of corelation matrices we made. With posibility to add bridges pictures"*
#
#
# | Label | Segment|
# |-------|-----------------------------------|
# |FEO	|First N seconds of Eyes Open       |
# |LEO	|Last N seconds of Eyes Open        |
# |FEC	|First N seconds of Eyes Closed|
# |LEC	|Last N seconds of Eyes Closed|
#
# <h3>What does each comparison tells us ?</h3>
#
# **FEO vs LEO & FEC vs LEC**
# - How much different is in state signal on the start than on the end
#
# **FEO vs FEC & LEO vs LEC**
# - How does signal differ after time spend in chage
#
# **FEO vs LEC**
# - Change at the beggining of task comp to the end of task
#
# **FEC vs LEO**
# - Dirrect chenge in eyes open and eyes closed state
#
# Info: could be comaprison between RS_before * RS_after but that would be shady since our interest would be just if the change is positive or negative.
#
# can be done in csv 4 state than make paper from that with cross comparison
#
# **Comparison using mean, std and median**
#
# - mean : standard avarage given by sum of numbers devided by number of observation
# - std : how close are numbers in set close to their avarage (mean)
# - meadian : middle number of odd data set or avarage of two middle numbers in even data set
#     - meadian 25% and median 75%
#
# **10s issue**
# lot of the time, the change between EO EC is not solidly in the middle...
# I have notes, but I suppose it is not valuable to go with perfectly beggining, the end and the middle with exp. That control patient will be focused on what he is supposed to do.

# %% [markdown]
# <h2>PDF Scheme</h2>
#
# PLV an Correlation comparison
#
# Supposed Bridges
#
# Print notes x readmes.md
#
# These 10 second snipplets I will be using: Probably will be comparing second or third 10th seconds from start, as close to the middle as I can get and then last 10 seconds or something -> Probably print them alfa, beta, gama... -how much of them in which part-if that would be possible
#
# Compare everything with everything using mean, std, median, meadian 25 & 75

# %% [markdown]
# <h3>Data: mean, std, median</h3>
#
# - Now we have to select 2nd 10 seconds after start, before finish for: FEO, LEC
# - For LEO and FEC we can work with EyesClosed.md. If ther **are** data, we take them. If not we can do
#
#     a)**get recordings**: Slow... option when after the other.
#
#     b)**work from alpha power**: Second option, faster but I am lame
#
#     c)**guess +- 4:30 and 5:30 or any other based number**
#
# *Lets assume: known deviation based on known data* $131/8=16.375$.*Which is almost 20 and give or take 4:30 to 4:40 for LEO and 5:20 to 5:30 for FEC*
#
# 1) vezmi get data
# 2) izoluj štyry windows podle: FOE prvých 10-20 seconds, LOE koukni do eyesopen.md if err then nic else vezmi 4:30-4:40. FEC je 5:20 to 5:30 and LEC 9:40 - 9:50.
# 3) Vezmu 3 matrix a dosadim do nich hodnoty mean, std, and median percentiles. Whatever else
# 4)

# %% [markdown]
# <b> stupid-ass questions... </b>
#
# *Should I take 10 matrices or take one matrice as 10 seconds correlation?*
# - 10 ≤ t < 20; where t is matrice or **15 ≤ t < 25** since there is center for matrices.
# - *Define by window centre*
#
# FEO:
# 10-20 s
#
# LEO:
# 270-280 s (4:30-4:40)
#
# FEC:
# 320-330 s (5:20-5:30)
#
# LEC:
# 580-590 s (9:40-9:50)
#
# *Should I MEAN each matrice or MEAN the values of the matrices?*
# - mean matrices element wise, do not make one number from each matrice

# %% [markdown]
# 1. get data -> get parameters from name specification
# > input corr_matrices || plv_matrices, subjects, before || after, sf250_win10_step1_bp1-45
#
# > get metadata file with parameters for analysis :
# ```json
#     "subject": "C09",
#     "recording": "RS_before",
#     "original_sfreq": 8000,
#     "target_sfreq": 250,
#     "window_length_s": 10,
#     "step_s": 1,
#     "overlap_s": 9,
#     "highpass_Hz": 1.0,
#     "lowpass_Hz": 45.0,
#     "n_channels": 124,
# ```
#
# 2. import config FEO...LEC and create NONcentre windows by MEAN elements
# > non centre because fuck that
#
# 4. make matrics for mean, std, median...
# > save matrics in results, quantifying data, corr || plv, subject ... so on so far
# >
# > create json with metadata for selected matrices, state, atd, etc
#
# > visualise data
